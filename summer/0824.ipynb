# %% [markdown]
# # 0824
# $$(f_1\epsilon^{-1}_1+f_2\epsilon^{-1}_2)^{-1}\leq\epsilon_\alpha\leq f_1\epsilon_1+f_2\epsilon_2$$
# $$f=\frac{3\times10^{14}}{\sqrt{\epsilon_a}} and \frac{3\times10^{14}}{\sqrt{\epsilon_b}} $$
# ## 15AB (omega 250~350)
# ![15AB(250-350THz).png](attachment:31029048-7672-415f-a562-ea2429920da0.png)
# ## 90° Bend waveguide
# ![band.png](attachment:e8408676-f96b-4b38-8ce6-e374bccafd4a.png)
