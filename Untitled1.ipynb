# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

def metal_cavity(w):
    resolution = 50
    sxy = 2
    dpml = 1
    sxy = sxy+2*dpml
    cell = mp.Vector3(sxy,sxy)

    pml_layers = [mp.PML(dpml)]
    a = 1
    t = 0.1
    geometry = [mp.Block(mp.Vector3(a+2*t,a+2*t,mp.inf), material=mp.metal),
                mp.Block(mp.Vector3(a,a,mp.inf), material=mp.air)]

    geometry.append(mp.Block(center=mp.Vector3(a/2),
                             size=mp.Vector3(2*t,w,mp.inf),
                             material=mp.air))

    fcen = math.sqrt(0.5)/a
    df = 0.2
    sources = [mp.Source(src=mp.GaussianSource(fcen,fwidth=df),
                         component=mp.Ez,
                         center=mp.Vector3())]

    symmetries = [mp.Mirror(mp.Y)]

    sim = mp.Simulation(cell_size=cell,
                        geometry=geometry,
                        boundary_layers=pml_layers,
                        sources=sources,
                        symmetries=symmetries,
                        resolution=resolution)

    h = mp.Harminv(mp.Ez, mp.Vector3(), fcen, df)
    sim.run(mp.after_sources(h), until_after_sources=500)

    m = h.modes[0]
    f = m.freq
    Q = m.Q
    Vmode = 0.25*a*a
    ldos_1 = Q / Vmode / (2 * math.pi * f * math.pi * 0.5)
        
    sim.reset_meep()
    
    T = 2*Q*(1/f)
    sim.run(mp.dft_ldos(f,0,1), until_after_sources=T)
    ldos_2 = sim.ldos_data[0]

    return ldos_1, ldos_2

# %%
ws = np.arange(0.2,0.5,0.1)
ldos_1 = np.zeros(len(ws))
ldos_2 = np.zeros(len(ws))

for j in range(len(ws)):
    ldos_1[j], ldos_2[j] = metal_cavity(ws[j])
    print("ldos:, {}, {}".format(ldos_1[j],ldos_2[2]))
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.0463922 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.025034 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=550.0)
# Meep progress: 187.86/550.0 = 34.2% done in 4.0s, 7.7s to go
# on time step 18859 (time=188.59), 0.000212106 s/step
# Meep progress: 388.1/550.0 = 70.6% done in 8.0s, 3.3s to go
# on time step 38915 (time=389.15), 0.000199444 s/step
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# harminv0:, 0.6740278049365257, -4.181510345180534e-05, 8059.621396290303, 6.2842179538537035, -3.8309426910424116-4.98149308837079i, 5.580514179738419e-12+0.0i
# run 0 finished at t = 550.0 (55000 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00103784 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0402539 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=23964.80392132871)
# Meep progress: 213.0/23964.80392132871 = 0.9% done in 4.0s, 446.0s to go
# on time step 21344 (time=213.44), 0.000187411 s/step
# Meep progress: 420.90000000000003/23964.80392132871 = 1.8% done in 8.0s, 447.5s to go
# on time step 42135 (time=421.35), 0.000192392 s/step
# Meep progress: 633.61/23964.80392132871 = 2.6% done in 12.0s, 441.9s to go
# on time step 63411 (time=634.11), 0.000188008 s/step
# Meep progress: 850.6700000000001/23964.80392132871 = 3.5% done in 16.0s, 434.8s to go
# on time step 85110 (time=851.1), 0.00018435 s/step
# Meep progress: 1062.94/23964.80392132871 = 4.4% done in 20.0s, 430.9s to go
# on time step 106348 (time=1063.48), 0.000188352 s/step
# Meep progress: 1272.92/23964.80392132871 = 5.3% done in 24.0s, 427.8s to go
# on time step 127349 (time=1273.49), 0.000190471 s/step
# Meep progress: 1483.95/23964.80392132871 = 6.2% done in 28.0s, 424.2s to go
# on time step 148449 (time=1484.49), 0.000189574 s/step
# Meep progress: 1703.69/23964.80392132871 = 7.1% done in 32.0s, 418.1s to go
# on time step 170431 (time=1704.31), 0.00018197 s/step
# Meep progress: 1915.2/23964.80392132871 = 8.0% done in 36.0s, 414.5s to go
# on time step 191586 (time=1915.86), 0.000189084 s/step
# Meep progress: 2128.9700000000003/23964.80392132871 = 8.9% done in 40.0s, 410.3s to go
# on time step 212966 (time=2129.66), 0.000187093 s/step
# Meep progress: 2306.59/23964.80392132871 = 9.6% done in 44.0s, 413.2s to go
# on time step 230707 (time=2307.07), 0.000225467 s/step
# Meep progress: 2464.65/23964.80392132871 = 10.3% done in 48.0s, 418.7s to go
# on time step 246536 (time=2465.36), 0.000252703 s/step
# Meep progress: 2647.26/23964.80392132871 = 11.0% done in 52.0s, 418.8s to go
# on time step 264787 (time=2647.87), 0.000219177 s/step
# Meep progress: 2800.19/23964.80392132871 = 11.7% done in 56.0s, 423.3s to go
# on time step 280090 (time=2800.9), 0.000261397 s/step
# Meep progress: 2973.37/23964.80392132871 = 12.4% done in 60.0s, 423.6s to go
# on time step 297425 (time=2974.25), 0.000230754 s/step
# Meep progress: 3130.92/23964.80392132871 = 13.1% done in 64.0s, 425.9s to go
# on time step 313178 (time=3131.78), 0.000253934 s/step
# Meep progress: 3282.6/23964.80392132871 = 13.7% done in 68.0s, 428.5s to go
# on time step 328367 (time=3283.67), 0.000263357 s/step
# Meep progress: 3464.48/23964.80392132871 = 14.5% done in 72.0s, 426.1s to go
# on time step 346552 (time=3465.52), 0.000219966 s/step
# Meep progress: 3622.3/23964.80392132871 = 15.1% done in 76.0s, 426.8s to go
# on time step 362317 (time=3623.17), 0.000253761 s/step
# Meep progress: 3797.01/23964.80392132871 = 15.8% done in 80.0s, 424.9s to go
# on time step 379827 (time=3798.27), 0.000228448 s/step
# Meep progress: 3966.6/23964.80392132871 = 16.6% done in 84.0s, 423.5s to go
# on time step 396691 (time=3966.91), 0.000237205 s/step
# Meep progress: 4144.65/23964.80392132871 = 17.3% done in 88.0s, 420.8s to go
# on time step 414573 (time=4145.73), 0.000223852 s/step
# Meep progress: 4334.96/23964.80392132871 = 18.1% done in 92.0s, 416.6s to go
# on time step 433612 (time=4336.12), 0.000210098 s/step
# Meep progress: 4487.22/23964.80392132871 = 18.7% done in 96.0s, 416.7s to go
# on time step 448857 (time=4488.57), 0.000262382 s/step
# Meep progress: 4657.89/23964.80392132871 = 19.4% done in 100.0s, 414.5s to go
# on time step 465866 (time=4658.66), 0.000235253 s/step
# Meep progress: 4829.1/23964.80392132871 = 20.2% done in 104.0s, 412.1s to go
# on time step 483029 (time=4830.29), 0.000233067 s/step
# Meep progress: 4987.89/23964.80392132871 = 20.8% done in 108.0s, 410.9s to go
# on time step 498980 (time=4989.8), 0.000250771 s/step
# Meep progress: 5171.78/23964.80392132871 = 21.6% done in 112.0s, 407.0s to go
# on time step 517321 (time=5173.21), 0.000218103 s/step
# Meep progress: 5327.56/23964.80392132871 = 22.2% done in 116.0s, 405.8s to go
# on time step 532875 (time=5328.75), 0.000257175 s/step
# Meep progress: 5495.84/23964.80392132871 = 22.9% done in 120.0s, 403.3s to go
# on time step 549747 (time=5497.47), 0.000237088 s/step
# Meep progress: 5672.04/23964.80392132871 = 23.7% done in 124.0s, 399.9s to go
# on time step 567346 (time=5673.46), 0.000227295 s/step
# Meep progress: 5827.02/23964.80392132871 = 24.3% done in 128.0s, 398.5s to go
# on time step 582856 (time=5828.56), 0.000257908 s/step
# Meep progress: 6010.45/23964.80392132871 = 25.1% done in 132.0s, 394.3s to go
# on time step 601213 (time=6012.13), 0.000217901 s/step
# Meep progress: 6173.18/23964.80392132871 = 25.8% done in 136.0s, 392.0s to go
# on time step 617474 (time=6174.74), 0.000245993 s/step
# Meep progress: 6340.14/23964.80392132871 = 26.5% done in 140.0s, 389.2s to go
# on time step 634190 (time=6341.9), 0.000239304 s/step
# Meep progress: 6511.83/23964.80392132871 = 27.2% done in 144.0s, 386.0s to go
# on time step 651299 (time=6512.99), 0.000233807 s/step
# Meep progress: 6660.89/23964.80392132871 = 27.8% done in 148.0s, 384.5s to go
# on time step 666255 (time=6662.55), 0.000267452 s/step
# Meep progress: 6842.8/23964.80392132871 = 28.6% done in 152.0s, 380.4s to go
# on time step 684462 (time=6844.62), 0.000219777 s/step
# Meep progress: 7000.91/23964.80392132871 = 29.2% done in 156.0s, 378.0s to go
# on time step 700233 (time=7002.33), 0.000253639 s/step
# Meep progress: 7162.610000000001/23964.80392132871 = 29.9% done in 160.0s, 375.4s to go
# on time step 716469 (time=7164.69), 0.000246368 s/step
# Meep progress: 7339.99/23964.80392132871 = 30.6% done in 164.0s, 371.5s to go
# on time step 734155 (time=7341.55), 0.000226175 s/step
# Meep progress: 7490.38/23964.80392132871 = 31.3% done in 168.0s, 369.5s to go
# on time step 749189 (time=7491.89), 0.000266131 s/step
# Meep progress: 7673.92/23964.80392132871 = 32.0% done in 172.0s, 365.2s to go
# Meep progress: 18631.0/23964.80392132871 = 77.7% done in 424.0s, 121.4s to go
# on time step 1863585 (time=18635.9), 0.000210033 s/step
# Meep progress: 18803.36/23964.80392132871 = 78.5% done in 428.0s, 117.5s to go
# on time step 1880657 (time=18806.6), 0.000234313 s/step
# Meep progress: 18974.89/23964.80392132871 = 79.2% done in 432.0s, 113.6s to go
# on time step 1897955 (time=18979.5), 0.00023126 s/step
# Meep progress: 19154.600000000002/23964.80392132871 = 79.9% done in 436.0s, 109.5s to go
# on time step 1915863 (time=19158.6), 0.000223371 s/step
# Meep progress: 19310.98/23964.80392132871 = 80.6% done in 440.0s, 106.0s to go
# on time step 1931530 (time=19315.3), 0.000255323 s/step
# Meep progress: 19496.86/23964.80392132871 = 81.4% done in 444.0s, 101.8s to go
# on time step 1950167 (time=19501.7), 0.00021463 s/step
# Meep progress: 19665.11/23964.80392132871 = 82.1% done in 448.0s, 98.0s to go
# on time step 1966835 (time=19668.4), 0.000239981 s/step
# Meep progress: 19831.760000000002/23964.80392132871 = 82.8% done in 452.0s, 94.2s to go
# on time step 1983646 (time=19836.5), 0.000237946 s/step
# Meep progress: 20002.07/23964.80392132871 = 83.5% done in 456.0s, 90.3s to go
# on time step 2000521 (time=20005.2), 0.000237057 s/step
# Meep progress: 20141.350000000002/23964.80392132871 = 84.0% done in 460.0s, 87.3s to go
# on time step 2014548 (time=20145.5), 0.000285192 s/step
# Meep progress: 20329.63/23964.80392132871 = 84.8% done in 464.0s, 83.0s to go
# on time step 2033578 (time=20335.8), 0.0002102 s/step
# Meep progress: 20497.71/23964.80392132871 = 85.5% done in 468.0s, 79.2s to go
# on time step 2050002 (time=20500), 0.000243551 s/step
# Meep progress: 20614.53/23964.80392132871 = 86.0% done in 472.0s, 76.7s to go
# on time step 2061807 (time=20618.1), 0.000338903 s/step
# Meep progress: 20750.100000000002/23964.80392132871 = 86.6% done in 476.0s, 73.7s to go
# on time step 2075397 (time=20754), 0.000294341 s/step
# Meep progress: 20885.510000000002/23964.80392132871 = 87.2% done in 480.0s, 70.8s to go
# on time step 2088921 (time=20889.2), 0.000295775 s/step
# Meep progress: 21015.350000000002/23964.80392132871 = 87.7% done in 484.0s, 67.9s to go
# on time step 2101939 (time=21019.4), 0.000307274 s/step
# Meep progress: 21131.84/23964.80392132871 = 88.2% done in 488.0s, 65.4s to go
# on time step 2113463 (time=21134.6), 0.000347109 s/step
# Meep progress: 21253.91/23964.80392132871 = 88.7% done in 492.0s, 62.8s to go
# on time step 2125685 (time=21256.9), 0.000327294 s/step
# Meep progress: 21391.32/23964.80392132871 = 89.3% done in 496.0s, 59.7s to go
# on time step 2139546 (time=21395.5), 0.000288645 s/step
# Meep progress: 21526.06/23964.80392132871 = 89.8% done in 500.0s, 56.6s to go
# on time step 2153054 (time=21530.5), 0.000296131 s/step
# Meep progress: 21666.64/23964.80392132871 = 90.4% done in 504.0s, 53.5s to go
# on time step 2167115 (time=21671.2), 0.000284482 s/step
# Meep progress: 21789.260000000002/23964.80392132871 = 90.9% done in 508.0s, 50.7s to go
# on time step 2179259 (time=21792.6), 0.000329544 s/step
# Meep progress: 21915.57/23964.80392132871 = 91.4% done in 512.0s, 47.9s to go
# on time step 2191933 (time=21919.3), 0.000315608 s/step
# Meep progress: 22065.28/23964.80392132871 = 92.1% done in 516.0s, 44.4s to go
# on time step 2207224 (time=22072.2), 0.000261601 s/step
# Meep progress: 22267.73/23964.80392132871 = 92.9% done in 520.0s, 39.6s to go
# on time step 2227325 (time=22273.2), 0.000199001 s/step
# Meep progress: 22447.68/23964.80392132871 = 93.7% done in 524.0s, 35.4s to go
# on time step 2245332 (time=22453.3), 0.000222138 s/step
# Meep progress: 22579.84/23964.80392132871 = 94.2% done in 528.0s, 32.4s to go
# on time step 2258212 (time=22582.1), 0.00031056 s/step
# Meep progress: 22696.73/23964.80392132871 = 94.7% done in 532.0s, 29.7s to go
# on time step 2270027 (time=22700.3), 0.000338561 s/step
# Meep progress: 22819.21/23964.80392132871 = 95.2% done in 536.0s, 26.9s to go
# on time step 2282360 (time=22823.6), 0.00032435 s/step
# Meep progress: 22976.28/23964.80392132871 = 95.9% done in 540.0s, 23.2s to go
# on time step 2298110 (time=22981.1), 0.000253972 s/step
# Meep progress: 23134.19/23964.80392132871 = 96.5% done in 544.0s, 19.5s to go
# on time step 2313855 (time=23138.5), 0.000254059 s/step
# Meep progress: 23258.2/23964.80392132871 = 97.1% done in 548.0s, 16.6s to go
# on time step 2326161 (time=23261.6), 0.00032506 s/step
# Meep progress: 23448.4/23964.80392132871 = 97.8% done in 552.0s, 12.2s to go
# on time step 2345570 (time=23455.7), 0.000206091 s/step
# Meep progress: 23630.05/23964.80392132871 = 98.6% done in 556.0s, 7.9s to go
# on time step 2363718 (time=23637.2), 0.000220426 s/step
# Meep progress: 23812.71/23964.80392132871 = 99.4% done in 560.0s, 3.6s to go
# on time step 2382021 (time=23820.2), 0.000218553 s/step
# ldos1:, 0.6740278049365257, 4395.243600123077
# run 1 finished at t = 23964.81 (2396481 timesteps)
# ldos:, 4846.152479766892, 0.0
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00159311 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.3,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.029232 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=550.0)
# Meep progress: 158.3/550.0 = 28.8% done in 4.0s, 9.9s to go
# on time step 15899 (time=158.99), 0.000251599 s/step
# Meep progress: 349.45/550.0 = 63.5% done in 8.0s, 4.6s to go
# on time step 34997 (time=349.97), 0.000209537 s/step
# Meep progress: 533.35/550.0 = 97.0% done in 12.0s, 0.4s to go
# on time step 53415 (time=534.15), 0.000217185 s/step
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# harminv0:, 0.668751367729982, -0.00026304052690668883, 1271.1945486012794, 4.905324930853104, 0.7951545788126869+4.840448519821508i, 1.1250535214233363e-11+0.0i
# run 0 finished at t = 550.0 (55000 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00113106 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.3,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0636919 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=3851.6955476778703)
# Meep progress: 170.23/3851.6955476778703 = 4.4% done in 4.0s, 86.5s to go
# on time step 17044 (time=170.44), 0.00023469 s/step
# Meep progress: 353.47/3851.6955476778703 = 9.2% done in 8.0s, 79.2s to go
# on time step 35414 (time=354.14), 0.000217753 s/step
# Meep progress: 544.59/3851.6955476778703 = 14.1% done in 12.0s, 72.9s to go
# on time step 54534 (time=545.34), 0.000209213 s/step
# Meep progress: 749.49/3851.6955476778703 = 19.5% done in 16.0s, 66.2s to go
# on time step 75021 (time=750.21), 0.000195253 s/step
# Meep progress: 950.1800000000001/3851.6955476778703 = 24.7% done in 20.0s, 61.1s to go
# on time step 95102 (time=951.02), 0.000199216 s/step
# Meep progress: 1165.4/3851.6955476778703 = 30.3% done in 24.0s, 55.3s to go
# on time step 116620 (time=1166.2), 0.000185897 s/step
# Meep progress: 1382.06/3851.6955476778703 = 35.9% done in 28.0s, 50.0s to go
# on time step 138294 (time=1382.94), 0.000184557 s/step
# Meep progress: 1600.22/3851.6955476778703 = 41.5% done in 32.0s, 45.0s to go
# on time step 160118 (time=1601.18), 0.000183285 s/step
# Meep progress: 1804.91/3851.6955476778703 = 46.9% done in 36.0s, 40.8s to go
# on time step 180556 (time=1805.56), 0.000195723 s/step
# Meep progress: 1982.26/3851.6955476778703 = 51.5% done in 40.0s, 37.7s to go
# on time step 198308 (time=1983.08), 0.000225336 s/step
# Meep progress: 2170.02/3851.6955476778703 = 56.3% done in 44.0s, 34.1s to go
# on time step 217105 (time=2171.05), 0.000212807 s/step
# Meep progress: 2314.7400000000002/3851.6955476778703 = 60.1% done in 48.0s, 31.9s to go
# on time step 231517 (time=2315.17), 0.000277561 s/step
# Meep progress: 2446.07/3851.6955476778703 = 63.5% done in 52.0s, 29.9s to go
# on time step 244698 (time=2446.98), 0.000303486 s/step
# Meep progress: 2606.48/3851.6955476778703 = 67.7% done in 56.0s, 26.8s to go
# on time step 260742 (time=2607.42), 0.000249323 s/step
# Meep progress: 2762.84/3851.6955476778703 = 71.7% done in 60.0s, 23.6s to go
# on time step 276390 (time=2763.9), 0.000255626 s/step
# Meep progress: 2917.79/3851.6955476778703 = 75.8% done in 64.0s, 20.5s to go
# on time step 291893 (time=2918.93), 0.000258101 s/step
# Meep progress: 3076.62/3851.6955476778703 = 79.9% done in 68.0s, 17.1s to go
# on time step 307780 (time=3077.8), 0.000251779 s/step
# Meep progress: 3236.33/3851.6955476778703 = 84.0% done in 72.0s, 13.7s to go
# on time step 323764 (time=3237.64), 0.000250256 s/step
# Meep progress: 3420.92/3851.6955476778703 = 88.8% done in 76.0s, 9.6s to go
# on time step 342268 (time=3422.68), 0.000216176 s/step
# Meep progress: 3622.94/3851.6955476778703 = 94.1% done in 80.0s, 5.1s to go
# on time step 362472 (time=3624.72), 0.000197984 s/step
# Meep progress: 3826.34/3851.6955476778703 = 99.3% done in 84.0s, 0.6s to go
# on time step 382796 (time=3827.96), 0.000196818 s/step
# ldos1:, 0.668751367729982, 685.5049361497653
# run 1 finished at t = 3851.7000000000003 (385170 timesteps)
# ldos:, 770.3845854770547, 0.0
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00127697 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0234001 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=550.0)
# Meep progress: 193.12/550.0 = 35.1% done in 4.0s, 7.4s to go
# on time step 19324 (time=193.24), 0.000207007 s/step
# Meep progress: 286.2/550.0 = 52.0% done in 8.0s, 7.4s to go
# on time step 28632 (time=286.32), 0.000429756 s/step
# Meep progress: 418.29/550.0 = 76.1% done in 12.0s, 3.8s to go
# on time step 41857 (time=418.57), 0.000302469 s/step
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# harminv0:, 0.6569209082166819, -0.0017412645422180979, 188.63328698460364, 2.1681042059680453, 2.0296049846781745-0.7624824287193999i, 1.4430824386693974e-10+0.0i
# run 0 finished at t = 550.0 (55000 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00484204 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0466521 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=624.2952755048677)
# Meep progress: 138.21/624.2952755048677 = 22.1% done in 4.0s, 14.1s to go
# on time step 13838 (time=138.38), 0.000289061 s/step
# Meep progress: 274.2/624.2952755048677 = 43.9% done in 8.0s, 10.2s to go
# on time step 27466 (time=274.66), 0.000293525 s/step
# Meep progress: 412.53000000000003/624.2952755048677 = 66.1% done in 12.0s, 6.2s to go
# on time step 41296 (time=412.96), 0.000289261 s/step
# Meep progress: 552.87/624.2952755048677 = 88.6% done in 16.0s, 2.1s to go
# on time step 55309 (time=553.09), 0.000285512 s/step
# ldos1:, 0.6569209082166819, 98.45046179106858
# run 1 finished at t = 624.3000000000001 (62430 timesteps)
# ldos:, 116.37655414871135, 98.45046179106858

# %%
plt.figure(dpi=150)
plt.semilogy(1/ws,ldos_1,'bo-',label="2Q/(πωV)")
plt.semilogy(1/ws,ldos_2,'rs-',label="LDOS")
plt.xlabel('a/w')
plt.ylabel('LDOS')
plt.show()
