# %%
import math
import meep as mp
from meep import mpb

num_bands = 5

k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(0.5),       # X
            mp.Vector3(0.5, 0.5),  # M
            mp.Vector3()]          # Gamma

k_points = mp.interpolate(4, k_points)

geometry = [mp.Cylinder(0.38, material=mp.Medium(epsilon=8.9))]

geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1))

resolution = 32

ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)
ms.run_tm()
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 5 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 5 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.38, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.02452850341796875
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5
# Solving for bands 2 to 5...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 3.064323577227693 (197.348% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.9983019032964463 (101.709% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.841276564864303 (17.0719% change)
#     linmin: converged after 5 iterations.
#     switching to approximate line minimization (decrease time by 57.6385%)
#     iteration    4: trace = 0.8200085180377883 (2.56043% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.8120263563994683 (0.978185% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 59.7747%)
#     iteration    6: trace = 0.8088822872301615 (0.387939% change)
#     iteration    7: trace = 0.8075050271638421 (0.170412% change)
#     iteration    8: trace = 0.8072780116648284 (0.0281172% change)
#     iteration    9: trace = 0.8072383842550903 (0.00490889% change)
#     iteration   10: trace = 0.8072307308264814 (0.000948105% change)
#     iteration   11: trace = 0.8072292044180938 (0.000189092% change)
#     iteration   12: trace = 0.8072283931771311 (0.000100497% change)
#     iteration   13: trace = 0.8072281853654826 (2.57439e-05% change)
#     iteration   14: trace = 0.8072281360970565 (6.10341e-06% change)
# Finished solving for bands 2 to 5 after 14 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.399282, 0.399282, 0.489304, 0.498956
# elapsed time for k point: 0.04609060287475586
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.8139435084394424 (1.09682% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.8135074786101577 (0.0535844% change)
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.8134850665630211 (0.00275503% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8134845140036158 (6.7925e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8134844924749773 (2.64647e-06% change)
# Finished solving for bands 1 to 5 after 5 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.1, 0.0465867, 0.38581, 0.400199, 0.493065, 0.509109
# elapsed time for k point: 0.2263960838317871
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.8320064633356627 (1.15235% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.8313456444137314 (0.0794563% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.8313144033522933 (0.00375796% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8313132003896407 (0.000144706% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8313131064155983 (1.13043e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8313130985592689 (9.45051e-07% change)
# Finished solving for bands 1 to 5 after 6 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.2, 0.0924068, 0.356405, 0.402691, 0.497726, 0.534658
# elapsed time for k point: 0.1737995147705078
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.8587760351037511 (1.31349% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8575352004397541 (0.144593% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.8574822423533219 (0.00617581% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8574799430241389 (0.000268149% change)
#     linmin: converged after 1 iterations.
#     iteration    5: trace = 0.8574795366811914 (4.73881e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8574794917976278 (5.23436e-06% change)
# Finished solving for bands 1 to 5 after 6 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.3, 0.136372, 0.321866, 0.40597, 0.502959, 0.563476
# elapsed time for k point: 0.11458206176757812
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.8876862996125026 (1.62667% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8848913807577923 (0.315351% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.8847435769725738 (0.0167044% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8847277581293629 (0.00178797% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8847260540965129 (0.000192606% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8847259962146542 (6.54235e-06% change)
# Finished solving for bands 1 to 5 after 6 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.4, 0.175653, 0.287806, 0.408817, 0.507447, 0.588562
# elapsed time for k point: 0.17552804946899414
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.9049311614764224 (2.19001% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8986118247545661 (0.700769% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.8981462434933026 (0.0518246% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.89805729938741 (0.00990357% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8980474930756179 (0.00109195% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8980415717633508 (0.000659356% change)
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    7: trace = 0.892710724315038 (0.595375% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.8926828917716637 (0.0031178% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.4791%)
#     iteration    9: trace = 0.8926545959319863 (0.0031698% change)
#     switching back to exact line minimization
#     iteration   10: trace = 0.8926258891038306 (0.00321595% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 0.8925955832431681 (0.00339519% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 0.8925660695622863 (0.00330656% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 0.8925361546971835 (0.00335161% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 0.8925058227989362 (0.00339845% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 0.8924750506468851 (0.0034479% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 0.8924438093923744 (0.00350058% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 0.8924120659021991 (0.00355698% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 0.892379783787749 (0.00361747% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 0.8923469241994422 (0.00368231% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 0.8923134464552708 (0.00375172% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 0.8922793085610424 (0.00382585% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 0.8922444676703652 (0.00390478% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 0.8922088805247111 (0.00398858% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 0.8921725039082586 (0.00407722% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 52.8935%)
#     iteration   25: trace = 0.8921352951479161 (0.00417067% change)
#     switching back to exact line minimization
#     iteration   26: trace = 0.8920974200718318 (0.00424553% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 0.8920525114078166 (0.00503418% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 0.8920125607223642 (0.00447861% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 0.8919716254731236 (0.00458919% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 0.891929676503218 (0.00470306% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 0.8918866903983088 (0.00481957% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 0.8918426508018125 (0.00493792% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 57.1236%)
#     iteration   33: trace = 0.8917975498116892 (0.00505718% change)
#     iteration   34: trace = 0.8917518206551944 (0.00512788% change)
#     iteration   35: trace = 0.8916956958976332 (0.00629396% change)
#     switching back to exact line minimization
#     iteration   36: trace = 0.8916370142917764 (0.00658112% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 0.8915755149193719 (0.00689759% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 0.8915253471518472 (0.00562703% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 0.8914743157882131 (0.00572421% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 0.891422498899321 (0.00581266% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 0.891369985000438 (0.0058912% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 0.891316870498862 (0.00595893% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 0.8912632565260599 (0.00601532% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 55.2964%)
#     iteration   44: trace = 0.8912092453714329 (0.00606025% change)
#     switching back to exact line minimization
#     iteration   45: trace = 0.8911556159133246 (0.00601779% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 0.8910881968691974 (0.00756564% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 0.8910335564576696 (0.00613206% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 0.8909788707924924 (0.00613752% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 0.8909241998312782 (0.00613624% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 0.8908695895208771 (0.00612981% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 0.8908150716920366 (0.00611981% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 0.8907606645795121 (0.00610775% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 0.8907063738249433 (0.00609506% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 0.8906521938162058 (0.006083% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 0.8905981092304754 (0.00607265% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 0.8905440966721603 (0.00606493% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 0.89049012632441 (0.00606056% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 0.8904361635590766 (0.00606008% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 0.8903821704718304 (0.00606385% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 0.8903281073250087 (0.00607209% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 0.8902739338905858 (0.00608484% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 0.8902196106894921 (0.00610204% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 0.890165100122448 (0.00612346% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 0.8901103674821895 (0.00614878% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 0.8900553818288421 (0.00617759% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 0.8900001167004818 (0.00620937% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 0.8899445506213921 (0.00624357% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 0.8898886673630568 (0.00627961% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 0.8898324559096485 (0.00631688% change)
#     resetting CG direction...
#     large trace change predicted (5.68113%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 0.8330002636231554 (6.59753% change)
#     linmin: converged after 3 iterations.
#     iteration   71: trace = 0.8241386056102957 (1.06951% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 0.8231209358820966 (0.123559% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 0.8230606001995313 (0.00733038% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 0.823056251170643 (0.000528399% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 0.8230556639391888 (7.13477e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 0.8230555828714825 (9.8496e-06% change)
# Finished solving for bands 1 to 5 after 76 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.5, 0.196446, 0.26871, 0.409958, 0.509253, 0.533718
# elapsed time for k point: 1.7508230209350586
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.8226847281004078 (1.61709% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.819924911825894 (0.336028% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.819805459556058 (0.0145697% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8198000988398606 (0.000653903% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8197994146437759 (8.34589e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8197992984382889 (1.41749e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.8197992803103832 (2.21126e-06% change)
# Finished solving for bands 1 to 5 after 7 iterations.
# tmfreqs:, 7, 0.5, 0.1, 0, 0.509902, 0.199986, 0.273013, 0.400431, 0.51861, 0.525326
# elapsed time for k point: 0.21823406219482422
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.8166302432409511 (1.36909% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.815170871990623 (0.178866% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.8150837599040486 (0.0106869% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8150541838806343 (0.00362865% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8150482441626934 (0.000728754% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8150479075395691 (4.1301e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.8150478894404362 (2.22062e-06% change)
# Finished solving for bands 1 to 5 after 7 iterations.
# tmfreqs:, 8, 0.5, 0.2, 0, 0.538516, 0.20996, 0.284893, 0.379002, 0.505335, 0.539254
# elapsed time for k point: 0.13784146308898926
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.8157634008046317 (1.24376% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8144769005319947 (0.15783% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.8141885191813862 (0.0354132% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.8140348797677062 (0.018872% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8140110747852961 (0.00292436% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8140084887186296 (0.000317695% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.8140083482587825 (1.72553e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.8140083423260269 (7.28832e-07% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# tmfreqs:, 9, 0.5, 0.3, 0, 0.583095, 0.224432, 0.301317, 0.354625, 0.48189, 0.561132
# elapsed time for k point: 0.1458122730255127
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.8181987804773097 (1.35531% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8157887987516426 (0.294982% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.3806%)
#     iteration    3: trace = 0.815236500700557 (0.067724% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.8148707632586158 (0.0448728% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.8147670740359745 (0.0127254% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8147571439680925 (0.00121877% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.814756564030061 (7.11793e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.814756506783785 (7.02618e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# tmfreqs:, 10, 0.5, 0.4, 0, 0.640312, 0.239519, 0.316954, 0.333368, 0.462003, 0.576495
# elapsed time for k point: 0.11968493461608887
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.8178726540485393 (1.45742% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8149717788004831 (0.355316% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.8147431917340768 (0.0280524% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.8146653554510779 (0.00955393% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.8146143214846391 (0.0062646% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8146054407718524 (0.00109018% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.8146047653313964 (8.29163e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.8146046932053653 (8.85411e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# tmfreqs:, 11, 0.5, 0.5, 0, 0.707107, 0.246972, 0.323853, 0.323853, 0.453718, 0.581367
# elapsed time for k point: 0.12036275863647461
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.8209839418527667 (2.82813% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 55.9856%)
#     iteration    2: trace = 0.8163725915995871 (0.563268% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.8161270317691103 (0.0300839% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8161092153492577 (0.00218307% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8161082256879935 (0.000121266% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8161081534211062 (8.85506e-06% change)
# Finished solving for bands 1 to 5 after 6 iterations.
# tmfreqs:, 12, 0.4, 0.4, 0, 0.565685, 0.230284, 0.326021, 0.329229, 0.469467, 0.57271
# elapsed time for k point: 0.09917759895324707
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.8275922327763189 (2.75495% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8246739702209989 (0.353244% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.8245130980846791 (0.0195093% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.8244914528314591 (0.00262525% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.8244876787650705 (0.000457746% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8244871341400022 (6.60562e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.8244870836345823 (6.12568e-06% change)
# Finished solving for bands 1 to 5 after 7 iterations.
# tmfreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.186611, 0.338513, 0.34427, 0.502229, 0.551649
# elapsed time for k point: 0.10488748550415039
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 5...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.8444071789026099 (2.88482% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.8413677219494344 (0.360601% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.8409106277356493 (0.0543423% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.840162892813183 (0.0889592% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.8398452107319266 (0.0378191% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.8398180220481589 (0.0032374% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.8398166270986653 (0.000166102% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.839816533650416 (1.11272e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.8398165276308531 (7.16771e-07% change)
# Finished solving for bands 1 to 5 after 9 iterations.
# tmfreqs:, 14, 0.2, 0.2, 0, 0.282843, 0.12913, 0.360795, 0.365837, 0.525602, 0.53186
# elapsed time for k point: 0.1294558048248291
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 5...
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 0.8537177675594072 (3.44646% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.8422007018888196 (1.35821% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.8274084861642516 (1.77194% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 0.8209083962613509 (0.788694% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.8199739543716706 (0.113895% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.8197859567971462 (0.0229299% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.8196897025592469 (0.0117421% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.8196328477300158 (0.00693638% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.8196241166103702 (0.00106525% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.8196232099580125 (0.000110618% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.8196229045596158 (3.72608e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.8196227045119074 (2.44073e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.8196226438573539 (7.4003e-06% change)
# Finished solving for bands 1 to 5 after 13 iterations.
# tmfreqs:, 15, 0.1, 0.1, 0, 0.141421, 0.0657087, 0.385954, 0.388159, 0.501049, 0.514419
# elapsed time for k point: 0.22514891624450684
# solve_kpoint (0,0,0):
# Solving for bands 2 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.8101035633469109 (1.31312% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 67.5333%)
#     iteration    2: trace = 0.807719088120656 (0.294776% change)
#     iteration    3: trace = 0.8072727572963054 (0.0552734% change)
#     iteration    4: trace = 0.807251472385196 (0.00263668% change)
#     iteration    5: trace = 0.8072355469651543 (0.00197281% change)
#     iteration    6: trace = 0.807228705951837 (0.000847465% change)
#     iteration    7: trace = 0.8072282453044886 (5.70653e-05% change)
#     iteration    8: trace = 0.8072281292539722 (1.43764e-05% change)
#     iteration    9: trace = 0.8072281247025516 (5.63833e-07% change)
# Finished solving for bands 2 to 5 after 9 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.399282, 0.399282, 0.489304, 0.498956
# elapsed time for k point: 0.03655433654785156
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2469717902412949 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.26871017769986816 at Vector3<0.5, 0.0, 0.0> to 0.39928162900974035 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3238533330670201 at Vector3<0.5, 0.5, 0.0> to 0.40995801218946487 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.45371801245414 at Vector3<0.5, 0.5, 0.0> to 0.525601771169231 at Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
# Band 5 range: 0.49895647297711854 at Vector3<0.0, 0.0, 0.0> to 0.5885621284163365 at Vector3<0.4, 0.0, 0.0>
# Gap from band 1 (0.2469717902412949) to band 2 (0.26871017769986816), 8.430927901304283%
# Gap from band 3 (0.40995801218946487) to band 4 (0.45371801245414), 10.133429437903562%
# total elapsed time for run: 3.8570117950439453
# done
# Initializing eigensolver data
# Computing 5 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 5 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.38, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.022284269332885742
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5
# Solving for bands 2 to 5...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 4.856906296780517 (195.834% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 1.59632098703957 (101.053% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 1.195924538486195 (28.6792% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 1.098298295499732 (8.51062% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.077123063352555 (1.94677% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 57.6399%)
#     iteration    6: trace = 1.07063834264941 (0.603859% change)
#     switching back to exact line minimization
#     iteration    7: trace = 1.068632918966252 (0.187487% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.067857883351661 (0.0725522% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.5855%)
#     iteration    9: trace = 1.067502737505238 (0.0332633% change)
#     iteration   10: trace = 1.067343060710713 (0.0149591% change)
#     iteration   11: trace = 1.067296023706804 (0.00440702% change)
#     iteration   12: trace = 1.067285613367992 (0.000975399% change)
#     iteration   13: trace = 1.067283555982361 (0.000192768% change)
#     iteration   14: trace = 1.067283167576859 (3.6392e-05% change)
#     iteration   15: trace = 1.067283080727786 (8.1374e-06% change)
# Finished solving for bands 2 to 5 after 15 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.400038, 0.512157, 0.512158, 0.618581
# elapsed time for k point: 0.0632021427154541
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 1.074561920298647 (0.697458% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 60.3631%)
#     iteration    2: trace = 1.073591401320544 (0.0903584% change)
#     switching back to exact line minimization
#     iteration    3: trace = 1.07337163644016 (0.0204722% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 1.073332997660355 (0.00359982% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.073322558414396 (0.000972606% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.073321233878328 (0.000123405% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.073320858836889 (3.49421e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.073320751931188 (9.96027e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.1, 0.067847, 0.396664, 0.512586, 0.513361, 0.620557
# elapsed time for k point: 0.12010312080383301
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 1.091250910530976 (0.789905% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.089624867539634 (0.149118% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.089158469107468 (0.0428127% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.08905152439909 (0.0098195% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.089021093793199 (0.00279427% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.089014602553616 (0.000596064% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.089012666090241 (0.000177818% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 1.089012225415102 (4.04656e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.089012156197978 (6.35595e-06% change)
# Finished solving for bands 1 to 5 after 9 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.2, 0.133708, 0.385776, 0.513723, 0.518657, 0.624015
# elapsed time for k point: 0.21400141716003418
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.111053587920265 (1.0309% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.107817616887931 (0.291677% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.106684368344822 (0.102348% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.106371617715734 (0.0282641% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.106291413218361 (0.00724959% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.106269070144665 (0.00201966% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.4162%)
#     iteration    7: trace = 1.10626390450838 (0.000466943% change)
#     iteration    8: trace = 1.106262745926333 (0.000104729% change)
#     iteration    9: trace = 1.106262577495132 (1.52252e-05% change)
#     iteration   10: trace = 1.106262536702825 (3.6874e-06% change)
# Finished solving for bands 1 to 5 after 10 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.3, 0.195474, 0.366142, 0.515168, 0.530826, 0.621948
# elapsed time for k point: 0.18456244468688965
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.122020267927387 (1.26202% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.11711381799327 (0.438245% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.115346604681653 (0.15832% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.114846018425118 (0.0448918% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.114746871283055 (0.00889374% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.114713834086515 (0.00296369% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.114707761584828 (0.00054476% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.114706368128433 (0.000125007% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.114706135744601 (2.08471e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.114706073589361 (5.57593e-06% change)
# Finished solving for bands 1 to 5 after 10 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.4, 0.250942, 0.337258, 0.516371, 0.550448, 0.606927
# elapsed time for k point: 0.14279985427856445
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.121765187729004 (1.16097% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.117547382331614 (0.376705% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.4132%)
#     iteration    3: trace = 1.11615892794216 (0.124318% change)
#     iteration    4: trace = 1.115817314263045 (0.0306109% change)
#     iteration    5: trace = 1.115763851964542 (0.00479143% change)
#     iteration    6: trace = 1.115745562474368 (0.0016392% change)
#     iteration    7: trace = 1.115742203402898 (0.000301061% change)
#     iteration    8: trace = 1.115741435189385 (6.88523e-05% change)
#     iteration    9: trace = 1.115741268771322 (1.49155e-05% change)
#     iteration   10: trace = 1.115741234506831 (3.07101e-06% change)
# Finished solving for bands 1 to 5 after 10 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.5, 0.294424, 0.302893, 0.516837, 0.568658, 0.588914
# elapsed time for k point: 0.12207460403442383
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.126474165797806 (0.562952% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.123602844310071 (0.25522% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.122468795287887 (0.100981% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.122213051929057 (0.0227866% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.122175485033107 (0.00334763% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.122171091745135 (0.000391498% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.12217030553007 (7.0062e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.122170158601933 (1.30932e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.122170131149903 (2.44633e-06% change)
# Finished solving for bands 1 to 5 after 9 iterations.
# tefreqs:, 7, 0.5, 0.1, 0, 0.509902, 0.304614, 0.304763, 0.504824, 0.582433, 0.58517
# elapsed time for k point: 0.13985228538513184
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.144394270815916 (0.655528% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.0171%)
#     iteration    2: trace = 1.141671049859309 (0.238245% change)
#     iteration    3: trace = 1.140708783164568 (0.0843213% change)
#     iteration    4: trace = 1.140474763739329 (0.0205174% change)
#     iteration    5: trace = 1.140425769197174 (0.00429607% change)
#     iteration    6: trace = 1.14042004063802 (0.000502319% change)
#     iteration    7: trace = 1.140418937654127 (9.67174e-05% change)
#     iteration    8: trace = 1.140418731020852 (1.81191e-05% change)
#     iteration    9: trace = 1.140418675105793 (4.90303e-06% change)
# Finished solving for bands 1 to 5 after 9 iterations.
# tefreqs:, 8, 0.5, 0.2, 0, 0.538516, 0.309375, 0.333174, 0.483781, 0.573385, 0.609004
# elapsed time for k point: 0.10538125038146973
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.171115571804918 (0.828379% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.168654526994656 (0.210366% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 1.168028169018559 (0.0536109% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.167877287483686 (0.0129185% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.167836299732117 (0.00350966% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.167829094210135 (0.000617% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.167825169165821 (0.000336098% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 1.167823100233204 (0.000177161% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.167822096066191 (8.59863e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.16782191962791 (1.51083e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.16782188457306 (3.00173e-06% change)
# Finished solving for bands 1 to 5 after 11 iterations.
# tefreqs:, 9, 0.5, 0.3, 0, 0.583095, 0.315913, 0.373444, 0.464204, 0.552485, 0.63862
# elapsed time for k point: 0.18759918212890625
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.203892720905422 (0.996892% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.201692379271077 (0.182936% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.201190740327721 (0.0417531% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.201031405854678 (0.0132656% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.200940275775324 (0.00758794% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.200903887363052 (0.00303004% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.200884031855013 (0.00165339% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.200877801246851 (0.000518836% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.200874061371994 (0.000311429% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 1.200871248017179 (0.000234276% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.200869885689107 (0.000113445% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.200869473759941 (3.43026e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 1.200869410754042 (5.24669e-06% change)
# Finished solving for bands 1 to 5 after 13 iterations.
# tefreqs:, 10, 0.5, 0.4, 0, 0.640312, 0.321926, 0.417411, 0.450138, 0.523251, 0.66827
# elapsed time for k point: 0.22343206405639648
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.238657197686182 (1.13947% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.235866760556501 (0.225533% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.234117688313537 (0.141626% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.232333659975728 (0.144664% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.23118388218239 (0.0933444% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 1.230917121591063 (0.0216693% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.2307437320861 (0.0140872% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.23049075738961 (0.0205567% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.229983822608839 (0.0412063% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 1.229545034950989 (0.0356806% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.229322641266237 (0.0180891% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.229215052742 (0.00875224% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 1.229190229770052 (0.00201944% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 1.229183362175903 (0.00055871% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 1.22918111824636 (0.000182555% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.22917904079201 (0.000169011% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.229177022306195 (0.000164214% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.22917552665213 (0.000121679% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.22917487677042 (5.28714e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.22917435007688 (4.28494e-05% change)
#     large trace change predicted (9.08659e-05%)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.229173232910011 (9.08876e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.229172102256927 (9.19849e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.229171657756699 (3.61626e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.229171556145088 (8.26667e-06% change)
# Finished solving for bands 1 to 5 after 24 iterations.
# tefreqs:, 11, 0.5, 0.5, 0, 0.707107, 0.324454, 0.444907, 0.444908, 0.501155, 0.69055
# elapsed time for k point: 0.34819483757019043
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.235374077526702 (2.55346% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.218945646280641 (1.33874% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.208058028671921 (0.897207% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 1.204284276145351 (0.31287% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.202581428104046 (0.141499% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.201779065582837 (0.0667423% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.201365502722315 (0.0344185% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.201215357920172 (0.0124986% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.201160780949775 (0.00454358% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.201122265725993 (0.00320655% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.201049065210535 (0.00609453% change)
#     large trace change predicted (0.0169949%)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.20084557904528 (0.0169438% change)
#     large trace change predicted (0.0353406%)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.200422725440796 (0.0352192% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 1.200075962041798 (0.0288909% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 1.199932034418041 (0.0119939% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 1.199889181730272 (0.00357132% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.199876264511593 (0.00107654% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.199871664791904 (0.00038335% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.199868976462155 (0.000224052% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.199867917260775 (8.82765e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.199867545854921 (3.09539e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.19986746774488 (6.50989e-06% change)
# Finished solving for bands 1 to 5 after 22 iterations.
# tefreqs:, 12, 0.4, 0.4, 0, 0.565685, 0.316636, 0.405128, 0.450879, 0.536103, 0.66692
# elapsed time for k point: 0.3983941078186035
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.179622538907632 (1.69333% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.175974418168845 (0.309741% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.174610427614291 (0.116055% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 1.174413198766028 (0.0167924% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.174344427760945 (0.00585595% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.174318271212648 (0.00222736% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.174307853734476 (0.000887113% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.174304416374603 (0.000292714% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.174303513548046 (7.68818e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.174303277018355 (2.01421e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.174303227298275 (4.23401e-06% change)
# Finished solving for bands 1 to 5 after 11 iterations.
# tefreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.270309, 0.37848, 0.466801, 0.559156, 0.653781
# elapsed time for k point: 0.20527172088623047
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.172345060551092 (1.56588% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.168238506883216 (0.3509% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.166850436626299 (0.118888% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.166330003306434 (0.0446115% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.166136792088251 (0.0165671% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.16605343708837 (0.00714822% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.166030578388063 (0.00196037% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.166012442516673 (0.00155536% change)
#     large trace change predicted (0.00709028%)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 1.165930138832985 (0.00705881% change)
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration   10: trace = 1.162731307364994 (0.274736% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.162592628834846 (0.0119277% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.162452734090651 (0.0120337% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.162310678972903 (0.012221% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.16216501618015 (0.012533% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 1.162014197267856 (0.0129783% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 1.16185672180387 (0.0135529% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 1.161691218198031 (0.0142458% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 1.161516527564126 (0.0150387% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 1.161331814317238 (0.015904% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 1.161136700439149 (0.0168023% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 1.160931396946427 (0.0176828% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 1.16071678662238 (0.0184878% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 1.16049440823782 (0.0191605% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 1.160266317427431 (0.0196566% change)
#     linmin: converged after 4 iterations.
#     iteration   25: trace = 1.160034844642815 (0.019952% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 1.159802312072565 (0.0200473% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 1.159570780999797 (0.019965% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 1.1593418793157 (0.0197422% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 1.159116725380506 (0.0194227% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 1.158895936718545 (0.0190498% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 1.158679695999011 (0.0186609% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 1.158467842487586 (0.0182857% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 1.158259961664434 (0.0179461% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 1.158055457274123 (0.0176577% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 1.157853600463514 (0.0174322% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 55.9495%)
#     iteration   36: trace = 1.157653558436773 (0.0172785% change)
#     switching back to exact line minimization
#     iteration   37: trace = 1.157458151631987 (0.016881% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 1.157198596904966 (0.0224271% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 1.156998325321516 (0.0173081% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 1.156795640381163 (0.0175197% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 1.156589254855453 (0.0178427% change)
#     linmin: converged after 4 iterations.
#     iteration   42: trace = 1.156377787731186 (0.0182854% change)
#     linmin: converged after 4 iterations.
#     iteration   43: trace = 1.156159778348175 (0.0188546% change)
#     linmin: converged after 4 iterations.
#     iteration   44: trace = 1.155933727051712 (0.0195538% change)
#     linmin: converged after 4 iterations.
#     iteration   45: trace = 1.155698184193144 (0.0203789% change)
#     linmin: converged after 4 iterations.
#     iteration   46: trace = 1.155451916449481 (0.0213113% change)
#     linmin: converged after 4 iterations.
#     iteration   47: trace = 1.155194179111428 (0.0223087% change)
#     linmin: converged after 4 iterations.
#     iteration   48: trace = 1.154925092971222 (0.0232963% change)
#     linmin: converged after 4 iterations.
#     iteration   49: trace = 1.154646040023737 (0.0241649% change)
#     linmin: converged after 4 iterations.
#     iteration   50: trace = 1.154359864032039 (0.0247878% change)
#     linmin: converged after 4 iterations.
#     iteration   51: trace = 1.154070608247951 (0.0250608% change)
#     linmin: converged after 4 iterations.
#     iteration   52: trace = 1.153782719925005 (0.0249486% change)
#     linmin: converged after 4 iterations.
#     iteration   53: trace = 1.153500041984468 (0.0245031% change)
#     linmin: converged after 4 iterations.
#     iteration   54: trace = 1.153225092120015 (0.023839% change)
#     linmin: converged after 4 iterations.
#     iteration   55: trace = 1.152958875975699 (0.0230872% change)
#     linmin: converged after 4 iterations.
#     iteration   56: trace = 1.152701107841191 (0.0223596% change)
#     linmin: converged after 4 iterations.
#     iteration   57: trace = 1.152450572845135 (0.021737% change)
#     linmin: converged after 4 iterations.
#     iteration   58: trace = 1.152205442490888 (0.0212726% change)
#     linmin: converged after 4 iterations.
#     iteration   59: trace = 1.151963473479499 (0.0210027% change)
#     linmin: converged after 4 iterations.
#     iteration   60: trace = 1.151722087397636 (0.0209565% change)
#     linmin: converged after 4 iterations.
#     iteration   61: trace = 1.151478346487772 (0.0211654% change)
#     linmin: converged after 4 iterations.
#     iteration   62: trace = 1.151228831442985 (0.0216715% change)
#     linmin: converged after 4 iterations.
#     iteration   63: trace = 1.150969404135786 (0.0225374% change)
#     linmin: converged after 4 iterations.
#     iteration   64: trace = 1.150694799979609 (0.0238614% change)
#     linmin: converged after 4 iterations.
#     iteration   65: trace = 1.150397923202199 (0.0258031% change)
#     linmin: converged after 4 iterations.
#     iteration   66: trace = 1.150068561629603 (0.0286343% change)
#     linmin: converged after 5 iterations.
#     iteration   67: trace = 1.149690843165934 (0.0328485% change)
#     linmin: converged after 5 iterations.
#     iteration   68: trace = 1.149237609361609 (0.03943% change)
#     linmin: converged after 6 iterations.
#     iteration   69: trace = 1.148655882911362 (0.0506313% change)
#     resetting CG direction...
#     large trace change predicted (2.0981%)
#     linmin: converged after 3 iterations.
#     iteration   70: trace = 1.122970249492688 (2.26143% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 1.117934297792735 (0.449457% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 1.117375851624105 (0.0499659% change)
#     linmin: converged after 3 iterations.
#     iteration   73: trace = 1.117194789847423 (0.0162055% change)
#     linmin: converged after 3 iterations.
#     iteration   74: trace = 1.117138723282554 (0.00501864% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 1.117119063843736 (0.00175982% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 1.117113779748499 (0.000473012% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 1.117111660376068 (0.000189719% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 1.117110660334918 (8.95203e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 1.117110136410405 (4.69e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 1.117109659000812 (4.27361e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 1.117109488627952 (1.52512e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 1.117109446229836 (3.79534e-06% change)
# Finished solving for bands 1 to 5 after 82 iterations.
# tefreqs:, 14, 0.2, 0.2, 0, 0.282843, 0.188534, 0.382901, 0.487303, 0.543893, 0.633772
# elapsed time for k point: 1.3288931846618652
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 5...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 1.084102409869788 (1.39765% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.080556532035301 (0.327615% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.079974085984649 (0.0539169% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 1.079820792893755 (0.0141952% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.079799305531107 (0.00198992% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 1.079795906935878 (0.000314744% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.079795320952605 (5.4268e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.079795175109966 (1.35065e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.079795150149902 (2.31156e-06% change)
# Finished solving for bands 1 to 5 after 9 iterations.
# tefreqs:, 15, 0.1, 0.1, 0, 0.141421, 0.095934, 0.394199, 0.50499, 0.521869, 0.622765
# elapsed time for k point: 0.17982912063598633
# solve_kpoint (0,0,0):
# Solving for bands 2 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.070308630802634 (1.13492% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.06773090386432 (0.24113% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 1.067383469786505 (0.0325448% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.067301049032393 (0.00772205% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.3723%)
#     iteration    5: trace = 1.067284488181896 (0.00155167% change)
#     iteration    6: trace = 1.067283323990958 (0.00010908% change)
#     iteration    7: trace = 1.067283086051709 (2.22939e-05% change)
#     iteration    8: trace = 1.067283056045663 (2.81144e-06% change)
# Finished solving for bands 2 to 5 after 8 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.400038, 0.512157, 0.512158, 0.618581
# elapsed time for k point: 0.031928300857543945
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3244535326029755 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.3028930543025848 at Vector3<0.5, 0.0, 0.0> to 0.44490732889178064 at Vector3<0.5, 0.5, 0.0>
# Band 3 range: 0.4449084020080457 at Vector3<0.5, 0.5, 0.0> to 0.5168369882809791 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.5011548894305318 at Vector3<0.5, 0.5, 0.0> to 0.582433425500867 at Vector3<0.5, 0.1, 0.0>
# Band 5 range: 0.5851704370846706 at Vector3<0.5, 0.1, 0.0> to 0.6905499407337892 at Vector3<0.5, 0.5, 0.0>
# Gap from band 2 (0.44490732889178064) to band 3 (0.4449084020080457), 0.00024119966141440064%
# Gap from band 4 (0.582433425500867) to band 5 (0.5851704370846706), 0.4688253733150309%
# total elapsed time for run: 4.024465799331665
# done

# %%
import matplotlib.pyplot as plt
import numpy as np 


fig, ax = plt.subplots()
x = range(len(tm_freqs))

for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([0, 0.8])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.1)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.1)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()
