# %% [markdown]
# # Fabey Perot in meep(AB)
#
# ## first of all load the library

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 定義參數

# %%
fmin = 0.05 #300THz
fmax = 0.265#600THz
nf = 1000 
fcen = (fmin + fmax)/2
df = fmax - fmin
#dfp = 1/2
fre = np.linspace(fmin,fmax,nf)
omega = 2 * np.pi * fre

# %%
dpml = 1

dA = 0.7 #700nm   750nm
dB = 0.35 #350nm  400nm
epsilonA = 13
epsilonB = 2

NAB = 15

sz = 2*dpml+16

resolution = 100 # pixels/μm

cell_size = mp.Vector3(z=sz)

pml_layers = [mp.PML(dpml)]

source_z=-sz/2+dpml
flux_reg_z=sz/2-dpml

# %% [markdown]
# ## geometry AB and BA

# %%
def BlockAB(N, center):
    geometry = []
    for i in range(N):
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA/2),
                     material=mp.Medium(epsilon=epsilonA)))
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA + dB/2),
                     material=mp.Medium(epsilon=epsilonB)))
    geometry = geometry.tolist()
    return geometry

# %%
def BlockBA(N, center):
    geometry = []
    for i in range(N):
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB/2),
                     material=mp.Medium(epsilon=epsilonB)))
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB + dA/2),
                     material=mp.Medium(epsilon=epsilonA)))
    geometry = geometry.tolist()
    return geometry

# %%
#geometry = sum([BlockAB(10,-10*(dA+dB)/2),BlockBA(10,10*(dA+dB)/2)],[])

# %% [markdown]
# ## Sources set up

# %%
sources = [mp.Source(mp.GaussianSource(fcen,fwidth=df),
                     component=mp.Ex,
                     center=mp.Vector3(z=source_z),
                     size=mp.Vector3())]

# %% [markdown]
# ## Simulation 真空

# %%
sim_vac = mp.Simulation(cell_size=cell_size,
                    resolution=resolution,
                    boundary_layers=pml_layers,
                    dimensions=1,
                    sources=sources)
refl_fr = mp.FluxRegion(center=mp.Vector3(z=-8))
refl = sim_vac.add_flux(fcen, df,nf, refl_fr)
tran_fr = mp.FluxRegion(center=mp.Vector3(z=8))
tran = sim_vac.add_flux(fcen, df, nf, tran_fr)
sim_vac.run(until_after_sources=mp.stop_when_fields_decayed(50,mp.Ex,
                                                            mp.Vector3(z=0),1e-3))
empty_flux = mp.get_fluxes(tran)
empty_data = sim_vac.get_flux_data(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
# time for set_epsilon = 0.000406027 s
# -----------
# field decay(t = 50.005): 0.2500056553228205 / 0.2500056553228205 = 1.0
# field decay(t = 100.01): 3.155121128080814e-08 / 0.2500056553228205 = 1.2620199027125026e-07
# run 0 finished at t = 100.01 (20002 timesteps)

# %% [markdown]
# ## Simulation 介質AB

# %%
sim = mp.Simulation(cell_size=cell_size,
                    resolution=resolution,
                    boundary_layers=pml_layers,
                    sources=sources,
                    dimensions=1,
                    geometry=BlockAB(NAB,0))
tran = sim.add_flux(fcen, df, nf, tran_fr)
refl = sim.add_flux(fcen, df, nf, refl_fr)
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex,
                                                        mp.Vector3(z=0), 1e-3))

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)
freqs = mp.get_flux_freqs(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00013113 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
#      block, center = (0,0,-7.525)
#           size (1e+20,1e+20,0.7)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-7)
#           size (1e+20,1e+20,0.35)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-6.475)
#           size (1e+20,1e+20,0.7)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-5.95)
#           size (1e+20,1e+20,0.35)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-5.425)
#           size (1e+20,1e+20,0.7)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-4.9)
#           size (1e+20,1e+20,0.35)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-4.375)
#           size (1e+20,1e+20,0.7)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-3.85)
#           size (1e+20,1e+20,0.35)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-3.325)
#           size (1e+20,1e+20,0.7)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-2.8)
#           size (1e+20,1e+20,0.35)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      ...(+ 20 objects not shown)...
# time for set_epsilon = 0.00104594 s
# -----------
# field decay(t = 50.005): 0.006300181894585699 / 0.006300181894585699 = 1.0
# field decay(t = 100.01): 0.01747499800224144 / 0.01747499800224144 = 1.0
# field decay(t = 150.01500000000001): 0.002580885916142693 / 0.01747499800224144 = 0.14769019806535338
# field decay(t = 200.02): 0.0014975340407339848 / 0.01747499800224144 = 0.08569580611922832
# field decay(t = 250.025): 0.00111411651610955 / 0.01747499800224144 = 0.06375488660809273
# field decay(t = 300.03000000000003): 0.00045952128358760377 / 0.01747499800224144 = 0.026295927674993894
# field decay(t = 350.035): 0.00029213815818149297 / 0.01747499800224144 = 0.016717493080343798
# field decay(t = 400.04): 0.00033226011890379823 / 0.01747499800224144 = 0.019013456760405962
# field decay(t = 450.045): 0.00017082481627015726 / 0.01747499800224144 = 0.00977538402283344
# field decay(t = 500.05): 0.0001287436198637573 / 0.01747499800224144 = 0.007367303838732567
# field decay(t = 550.0550000000001): 0.00012408740221372242 / 0.01747499800224144 = 0.007100853585093759
# field decay(t = 600.0600000000001): 9.218037463474704e-05 / 0.01747499800224144 = 0.005274986275988327
# field decay(t = 650.065): 7.245724489176157e-05 / 0.01747499800224144 = 0.0041463378068751595
# field decay(t = 700.07): 6.011226832568024e-05 / 0.01747499800224144 = 0.0034399012988711015
# field decay(t = 750.075): 5.3714403034889385e-05 / 0.01747499800224144 = 0.0030737859327937935
# field decay(t = 800.08): 4.759440424665932e-05 / 0.01747499800224144 = 0.0027235713698253125
# field decay(t = 850.085): 3.790426907116303e-05 / 0.01747499800224144 = 0.0021690571332998844
# field decay(t = 900.09): 3.213751813721425e-05 / 0.01747499800224144 = 0.0018390570421291102
# on time step 186633 (time=933.165), 2.14325e-05 s/step
# field decay(t = 950.095): 3.133070350925699e-05 / 0.01747499800224144 = 0.0017928873871824382
# field decay(t = 1000.1): 2.6112026926071656e-05 / 0.01747499800224144 = 0.0014942506386966328
# field decay(t = 1050.105): 2.0804069485301467e-05 / 0.01747499800224144 = 0.0011905048276762617
# field decay(t = 1100.1100000000001): 1.9874158514209865e-05 / 0.01747499800224144 = 0.001137291032116896
# field decay(t = 1150.115): 1.7435678785654998e-05 / 0.01747499800224144 = 0.0009977499730425491
# run 0 finished at t = 1150.115 (230023 timesteps)

# %%
wvls = np.empty(nf)
R = np.empty(nf)
T = np.empty(nf)
for i in range(nf):
        wvls[i] = 1/freqs[i]*2*np.pi*3*10
        R[i] = -refl_flux[i]/empty_flux[i]
        T[i] = tran_flux[i]/empty_flux[i]

# %%
plt.figure(dpi=150)#解析度
plt.plot(omega*300,T,'-',label='$T_{nur}$')#x軸omega y軸T
#plt.plot(omega/2/np.pi,R,'.',label='$T_{nur}$')
plt.xlabel("omega (THz)")
plt.ylabel("$T$")
#plt.xlim([fmin,fmax])
plt.ylim([0,1])
plt.savefig('15AB(250-350THz) < 1mu.png')
plt.show()
# Out:
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
