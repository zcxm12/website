# %% [markdown]
# # 0810
#
# ## 參考老師Fabey Perot interference 1 and 15

# %% [markdown]
# ![1and15 .png](attachment:a8dfaa41-99e0-4e4c-92b7-a976b8a18e8a.png)

# %% [markdown]
# ## 模擬AB 1層(有誤?)

# %% [markdown]
# ![AB.png](attachment:a3cc0194-8164-4ece-ab25-38d0a4db0f8f.png)

# %% [markdown]
# ## AB 10(有誤?)

# %% [markdown]
# ![AB15.png](attachment:5402a567-9aca-472d-b71e-4936b63e7b48.png)
