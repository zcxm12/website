# %%
import math
import meep as mp
from meep import mpb

geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)

kz = 0

k_points = [
    mp.Vector3(z=kz),  # Gamma
    mp.Vector3(0, 0.5, kz),  # M
    mp.Vector3(1 / -3, 1 / 3, kz),  # K
    mp.Vector3(z=kz),  # Gamma
]

k_interp = 4
k_points = mp.interpolate(k_interp, k_points)

eps = 13  # the dielectric constant of the background
r = 0.48  # the hole radius

default_material = mp.Medium(epsilon=eps)
geometry = [mp.Cylinder(r, material=mp.air)]



resolution = 32
num_bands = 15

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    geometry=geometry,
    k_points=k_points,
    default_material=default_material,
    resolution=resolution,
    num_bands=num_bands,
)

ms.run_tm()
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 15 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.48, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 16 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0791327953338623
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8, tm band 9, tm band 10, tm band 11, tm band 12, tm band 13, tm band 14, tm band 15
# Solving for bands 2 to 9...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 15.13392602403023 (195.536% change)
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 5.976563557983242 (86.7565% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 5.031599194983375 (17.1684% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 4.81164090676918 (4.46923% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.758268054286716 (1.11543% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.733745117739174 (0.516707% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.719712956395385 (0.296868% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.713012373153584 (0.142071% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.710187979003005 (0.0599455% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.708604501038052 (0.0336238% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 4.707382516176642 (0.0259555% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 4.706404776178301 (0.0207725% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 4.705779541851093 (0.0132856% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 4.70556991127794 (0.00445485% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.705509207674812 (0.00129005% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.705475366033333 (0.000719194% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.705439313607167 (0.000766183% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 4.705373907385636 (0.00139002% change)
#     large trace change predicted (0.00350256%)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 66.181%)
#     iteration   19: trace = 4.705210301866642 (0.00347705% change)
#     iteration   20: trace = 4.704724454319962 (0.0103263% change)
#     switching back to exact line minimization
#     iteration   21: trace = 4.703797976160215 (0.0196944% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 4.703072320229592 (0.0154282% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 4.702737732444778 (0.00711449% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 4.702636031271553 (0.00216262% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 4.7026042506752 (0.000675806% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 4.702586057877443 (0.000386867% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 65.8535%)
#     iteration   27: trace = 4.702578100613291 (0.000169211% change)
#     iteration   28: trace = 4.702574860064276 (6.89101e-05% change)
#     switching back to exact line minimization
#     iteration   29: trace = 4.702572260387161 (5.5282e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 4.702570072218742 (4.65313e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.3948%)
#     iteration   31: trace = 4.702569163223838 (1.93297e-05% change)
#     iteration   32: trace = 4.702568883407001 (5.9503e-06% change)
# Finished solving for bands 2 to 9 after 32 iterations.
# Solving for bands 10 to 15...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 23.53608402753043 (190.602% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 10.1868700640677 (79.1699% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 8.777371679811649 (14.8648% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.477807112838686 (3.47217% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 8.398590877165685 (0.938781% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 8.378047786868775 (0.244901% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 8.367824092147037 (0.122104% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 8.355506380265384 (0.147312% change)
#     large trace change predicted (0.332239%)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 8.329272615532403 (0.314463% change)
#     linmin: converged after 5 iterations.
#     iteration   10: trace = 8.297568780190797 (0.381357% change)
#     linmin: converged after 5 iterations.
#     iteration   11: trace = 8.27640326027943 (0.255407% change)
#     linmin: converged after 5 iterations.
#     iteration   12: trace = 8.257317849531683 (0.230866% change)
#     linmin: converged after 5 iterations.
#     iteration   13: trace = 8.236924479560834 (0.247279% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 8.223502955893391 (0.163076% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 8.217566224909509 (0.0722183% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 8.214164797289211 (0.0414007% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 8.212572840302274 (0.0193825% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 8.211880468228623 (0.00843099% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 8.211615111007912 (0.00323143% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 8.211504707370805 (0.00134449% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 8.211446135441866 (0.000713294% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 8.211415614001337 (0.000371695% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 8.211402764865603 (0.000156479% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 8.211397759308959 (6.09586e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 8.211395178732783 (3.14268e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 60.647%)
#     iteration   26: trace = 8.211393913092561 (1.54132e-05% change)
#     switching back to exact line minimization
#     iteration   27: trace = 8.211393421584228 (5.98569e-06% change)
# Finished solving for bands 10 to 15 after 27 iterations.
# Finished k-point with 27.8667 mean iterations/band.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.430473, 0.600264, 0.601313, 0.733578, 0.776373, 0.777748, 0.968641, 1.05419, 1.05619, 1.08417, 1.13477, 1.13741, 1.29108, 1.2931
# elapsed time for k point: 1.2637665271759033
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.586288418342174 (1.48445% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.574836773189034 (0.319828% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 3.573511175088684 (0.0370882% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.573321102218634 (0.00531908% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.573300057321937 (0.000588947% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.573295756441248 (0.000120362% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 3.573293962267303 (5.02106e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 3.573293463495149 (1.39583e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 3.5732934015262 (1.73423e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.364684852438202 (0.468202% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.345835566846151 (0.201483% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.329386900213747 (0.176155% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.325004295344328 (0.0469874% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.324025818997409 (0.0104936% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.323795087147079 (0.00247463% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.323727178312847 (0.000728342% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.323694540690262 (0.00035005% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.323678896110779 (0.000167794% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.32367586086465 (3.25542e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.323675412103803 (4.81313e-06% change)
# Finished solving for bands 9 to 15 after 11 iterations.
# Finished k-point with 9.93333 mean iterations/band.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0667472, 0.425194, 0.598733, 0.60357, 0.717688, 0.778131, 0.795364, 0.95504, 1.04204, 1.05413, 1.09645, 1.1389, 1.15256, 1.28329, 1.28534
# elapsed time for k point: 0.42939138412475586
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace =
-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.449191009655408 (5.06207e-06% change)
# Finished solving for bands 9 to 15 after 9 iterations.
# Finished k-point with 7.4 mean iterations/band.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.287846, 0.333448, 0.548866, 0.625339, 0.695183, 0.791531, 0.840453, 0.908338, 0.959462, 1.05122, 1.15589, 1.19301, 1.20809, 1.2288, 1.30184
# elapsed time for k point: 0.38869404792785645
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.534269736137712 (0.356288% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.533130989997079 (0.0322253% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 3.533058723184393 (0.00204543% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.533049275101874 (0.00026742% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.533048220110668 (2.98606e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.533047977928327 (6.85477e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.439559101327534 (0.149456% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.435485908325898 (0.0431596% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.43445733128887 (0.0109018% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 9.434257213323757 (0.00212116% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.434218950651129 (0.000405572% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.434211652354733 (7.73599e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.434209160811317 (2.64097e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.434208509875498 (6.89974e-06% change)
# Finished solving for bands 9 to 15 after 8 iterations.
# Finished k-point with 6.93333 mean iterations/band.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.295647, 0.332662, 0.533731, 0.642738, 0.68816, 0.792583, 0.835568, 0.914915, 0.953336, 1.05253, 1.15627, 1.186, 1.22431, 1.23124, 1.28807
# elapsed time for k point: 0.3249971866607666
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.544471095281275 (0.336258% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.543494821888245 (0.0275474% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 3.543435456372563 (0.00167535% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.543427839260994 (0.000214964% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.543426138385191 (4.80009e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.543424209200674 (5.44441e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 3.543422148732244 (5.81491e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 3.543421539506435 (1.71931e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 3.543421383843058 (4.39302e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.42335939051276 (0.140583% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.41988352074997 (0.0368925% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.418907830596638 (0.0103583% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 9.41866011640165 (0.00263% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.418602411146395 (0.000612671% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.418590826474754 (0.000122998% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.418587860170819 (3.14941e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.418587359359897 (5.31726e-06% change)
# Finished solving for bands 9 to 15 after 8 iterations.
# Finished k-point with 8.53333 mean iterations/band.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.305987, 0.328362, 0.523528, 0.657799, 0.679483, 0.793421, 0.831268, 0.923564, 0.944994, 1.05337, 1.16053, 1.17781, 1.23356, 1.24139, 1.27249
# elapsed time for k point: 0.4622960090637207
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.561150160576649 (0.318925% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.560275806575167 (0.0245556% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 3.560213819047025 (0.0017411% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.560199013934366 (0.00041585% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.560180240544943 (0.000527314% change)
#     large trace change predicted (0.00135902%)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 3.560131886451806 (0.0013582% change)
#     large trace change predicted (0.00384266%)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 3.559995804828471 (0.00382245% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 3.5597585235039 (0.00666544% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 3.559592829471933 (0.00465475% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 3.559565031342321 (0.000780939% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 3.559561253419816 (0.000106134% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 3.559560885075252 (1.0348e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 3.559560835445292 (1.39427e-06% change)
# Finished solving for bands 1 to 8 after 13 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.407192631070819 (0.142121% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.403589766081726 (0.0383064% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.6276%)
#     iteration    3: trace = 9.402304049338314 (0.0136736% change)
#     switching back to exact line minimization
#     iteration    4: trace = 9.401888434798844 (0.00442045% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.401786667255401 (0.00108242% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.401767349480027 (0.000205469% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.401762796141183 (4.84307e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.401762017696816 (8.27977e-06% change)
# Finished solving for bands 9 to 15 after 8 iterations.
# Finished k-point with 10.6667 mean iterations/band.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.318359, 0.318421, 0.519969, 0.669523, 0.669909, 0.793787, 0.829387, 0.933503, 0.935065, 1.05372, 1.16774, 1.1694, 1.23496, 1.25706, 1.25725
# elapsed time for k point: 0.5112035274505615
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 3.535152852156742 (1.35264% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.5286443912895 (0.184277% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 3.527122842147256 (0.0431292% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.526904714215825 (0.00618449% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.526878747984945 (0.000736236% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.526874254015687 (0.000127421% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 3.526873530139914 (2.05246e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 3.526873449656215 (2.28201e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.45747980567192 (0.596796% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.439312331517307 (0.192281% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.430536374025184 (0.0930157% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.427340853313579 (0.0338906% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.426420492798446 (0.00976315% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.426199819881365 (0.00234103% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.426144017263322 (0.000591997% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.426132195917342 (0.00012541% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.426129123097493 (3.2599e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.42612838039364 (7.8792e-06% change)
# Finished solving for bands 9 to 15 after 10 iterations.
# Finished k-point with 8.93333 mean iterations/band.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.279167, 0.347154, 0.532482, 0.649567, 0.681972, 0.792256, 0.838228, 0.909707, 0.95915, 1.05293, 1.14995, 1.19038, 1.21681, 1.24828, 1.27251
# elapsed time for k point: 0.4473392963409424
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 3.522165229776169 (1.2749% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.517154352644368 (0.142368% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 3.516358949648127 (0.0226175% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.516246806433024 (0.00318924% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.516236205549808 (0.000301483% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.516234398337328 (5.13962e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 3.516234105065851 (8.3405e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.436411141187019 (0.667546% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.415224203759715 (0.224776% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.406158582701666 (0.0963332% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.403400325778145 (0.0293282% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.402608219086066 (0.00842397% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.402397600198617 (0.00224003% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.402343840759901 (0.000571765% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.402333444874555 (0.000110567% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.402330828408836 (2.78278e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.402330322749144 (5.37803e-06% change)
# Finished solving for bands 9 to 15 after 10 iterations.
# Finished k-point with 8.4 mean iterations/band.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.220677, 0.377356, 0.559774, 0.63078, 0.684637, 0.788355, 0.853088, 0.892143, 0.985637, 1.05255, 1.13331, 1.18521, 1.20976, 1.25726, 1.26082
# elapsed time for k point: 0.33270907402038574
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.537863552619907 (1.27407% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.533234323583064 (0.130934% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 3.532767835437395 (0.0132037% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.532714064113428 (0.00152209% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.532709631386876 (0.000125477% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.532709298077499 (9.43495e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.373251352486069 (0.596137% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.36024412140373 (0.138866% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.3560637398864 (0.044671% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.355107594310475 (0.0102201% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.35488847939204 (0.00234222% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.354817444048262 (0.000759342% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.354789913415628 (0.000294294% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.35478385983739 (6.4711e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.35478258261889 (1.36531e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.354782343034774 (2.56109e-06% change)
# Finished solving for bands 9 to 15 after 10 iterations.
# Finished k-point with 7.86667 mean iterations/band.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.151571, 0.40438, 0.584907, 0.615336, 0.692481, 0.783041, 0.833027, 0.915883, 1.01285, 1.05278, 1.11742, 1.1577, 1.19581, 1.26073, 1.26975
# elapsed time for k point: 0.41514158248901367
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 3.576249992529203 (1.38539% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 64.6568%)
#     iteration    2: trace = 3.569468128096712 (0.189816% change)
#     iteration    3: trace = 3.568700798667445 (0.0214993% change)
#     switching back to exact line minimization
#     iteration    4: trace = 3.568602919775263 (0.00274274% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.56858517924833 (0.000497129% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.568580512010427 (0.000130787% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 3.568579125497553 (3.88534e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 3.568578827250514 (8.35759e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.34198683415692 (0.522306% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.332121854994657 (0.105654% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.327809347238871 (0.0462221% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.326143031654242 (0.0178655% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.325446700697954 (0.00746672% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.325241736807911 (0.00219792% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.325198164911139 (0.000467248% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.325189797072889 (8.97337e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.325185823639648 (4.26097e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.325183940649937 (2.01925e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.325183457301494 (5.18326e-06% change)
# Finished solving for bands 9 to 15 after 11 iterations.
# Finished k-point with 9.4 mean iterations/band.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0769778, 0.423489, 0.59741, 0.604999, 0.714209, 0.778297, 0.799894, 0.951166, 1.03923, 1.05351, 1.09894, 1.14016, 1.15734, 1.28099, 1.28348
# elapsed time for k point: 0.5231657028198242
# solve_kpoint (0,0,0):
# Solving for bands 2 to 9...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.739746636204363 (1.35261% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.723174712187352 (0.35025% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.718107349700146 (0.107345% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.715002989047201 (0.0658184% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 4.711522404442823 (0.0738466% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.708776350271906 (0.0583008% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.707292523668443 (0.0315169% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.706967074538085 (0.00691396% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 4.706877643386127 (0.00189999% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.706825151205724 (0.00111523% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.706800902781941 (0.000515177% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.706796925758 (8.44953e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.70679657665775 (7.41694e-06% change)
# Finished solving for bands 2 to 9 after 13 iterations.
# Solving for bands 10 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 8.249864786853482 (0.579858% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 59.3098%)
#     iteration    2: trace = 8.234465233778129 (0.186839% change)
#     switching back to exact line minimization
#     iteration    3: trace = 8.220033778161346 (0.17541% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.211501709919448 (0.10385% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 8.208282318891161 (0.0392136% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.884%)
#     iteration    6: trace = 8.207504300230491 (0.00947891% change)
#     iteration    7: trace = 8.207328151968314 (0.00214621% change)
#     iteration    8: trace = 8.207255427991534 (0.00088609% change)
#     switching back to exact line minimization
#     iteration    9: trace = 8.20719567766095 (0.000728021% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 8.207172231681339 (0.000285676% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 8.207166972469345 (6.40807e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace =
-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 13.78347543488614 (4.45318e-06% change)
# Finished solving for bands 9 to 15 after 13 iterations.
# Finished k-point with 13 mean iterations/band.
# tefreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.185697, 0.674556, 0.710238, 0.808725, 0.901085, 0.996785, 1.00186, 1.21096, 1.27981, 1.30396, 1.34482, 1.38305, 1.43876, 1.45931, 1.5888
# elapsed time for k point: 0.8789451122283936
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.893054416693875 (0.749456% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.883026952484447 (0.170302% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.879180784031572 (0.0653988% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.877187337787914 (0.0339126% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.875685248286834 (0.0255612% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.874641918677515 (0.0177583% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.874211061055168 (0.00733446% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.874040348986785 (0.00290617% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.874000648572299 (0.000675864% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.873988796839017 (0.000201766% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.873984107459051 (7.9833e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.873981575032888 (4.31126e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.87398034766016 (2.08951e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.873979913736525 (7.38722e-06% change)
# Finished solving for bands 1 to 8 after 14 iterations.
# Solving for bands 9 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 13.91031281908798 (0.349693% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 13.89417288224869 (0.116096% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 13.88852822543791 (0.0406343% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 13.88678837201269 (0.0125281% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 13.88599853616625 (0.00568784% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 13.88569237210607 (0.00220486% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 13.88557695034459 (0.000831231% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 13.88554041080065 (0.000263148% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 13.88552883859066 (8.334e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 13.88552535429469 (2.5093e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 13.88552421774629 (8.18513e-06% change)
# Finished solving for bands 9 to 15 after 11 iterations.
# Finished k-point with 12.6 mean iterations/band.
# tefreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0939544, 0.735946, 0.754289, 0.80075, 0.893127, 0.948286, 0.952237, 1.2287, 1.29871, 1.318, 1.32537, 1.39264, 1.42277, 1.49, 1.58786
# elapsed time for k point: 0.9571030139923096
# solve_kpoint (0,0,0):
# Solving for bands 2 to 9...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.590784487654654 (0.621741% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.578573338016496 (0.160998% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.572122314319006 (0.0851581% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.566636293261296 (0.0724765% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.560763785131755 (0.0776407% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.557356758790597 (0.0450721% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.55621164518586 (0.0151535% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.555855973947713 (0.00470712% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.555770228152179 (0.00113483% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.555742949464102 (0.000361032% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.555734467051733 (0.000112265% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.555730304244944 (5.50947e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 7.555727827926767 (3.2774e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 7.555726199566502 (2.15513e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 7.555725450974714 (9.90761e-06% change)
# Finished solving for bands 2 to 9 after 15 iterations.
# Solving for bands 10 to 15...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 12.36114994400426 (0.432362% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 12.3376836690283 (0.190019% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 12.32446366810674 (0.107209% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 12.31545581709353 (0.0731159% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 12.30702574862723 (0.0684746% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 12.30161700790044 (0.0439581% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 12.29864475579537 (0.0241644% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 12.29741894943866 (0.0099675% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 12.29691243585333 (0.00411895% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 12.29670245936022 (0.00170757% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 12.29660184209463 (0.000818249% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 12.29656484006127 (0.000300913% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 12.29655460064845 (8.32705e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 12.29655179347664 (2.28289e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 12.29655066733889 (9.15816e-06% change)
# Finished solving for bands 10 to 15 after 15 iterations.
# Finished k-point with 14 mean iterations/band.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.768798, 0.770619, 0.804599, 0.882617, 0.927373, 0.927393, 1.23843, 1.30025, 1.30431, 1.34829, 1.39459, 1.3997, 1.53391, 1.58762
# elapsed time for k point: 0.9681427478790283
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.36488998406249756 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.529921266047538 at Vector3<0.0, 0.5, 0.0> to 0.7687977993790629 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.5746238271286925 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.770619412085265 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.7774658096592912 at Vector3<0.0, 0.5, 0.0> to 0.8788507684764247 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.8793010366338008 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.9303613566386238 at Vector3<0.0, 0.5, 0.0>
# Band 6 range: 0.9273727392603018 at Vector3<0.0, 0.0, 0.0> to 1.111178300949064 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 7 range: 0.9273925147745219 at Vector3<0.0, 0.0, 0.0> to 1.1144668461713014 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 8 range: 1.151973695379281 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.2384307591167687 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 1.188320660772017 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.300279829499289 at Vector3<0.0, 0.1, 0.0>
# Band 10 range: 1.2624909687162573 at Vector3<0.0, 0.5, 0.0> to 1.3180018435039607 at Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
# Band 11 range: 1.3157186718713725 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.3687507575841178 at Vector3<0.0, 0.30000000000000004, 0.0>
# Band 12 range: 1.3656288182840535 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.4063963028696196 at Vector3<0.0, 0.5, 0.0>
# Band 13 range: 1.3997029007595745 at Vector3<0.0, 0.0, 0.0> to 1.448374094260813 at Vector3<0.0, 0.2, 0.0>
# Band 14 range: 1.4504461930160093 at Vector3<0.0, 0.2, 0.0> to 1.5348368247001694 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 15 range: 1.576186710031307 at Vector3<0.0, 0.5, 0.0> to 1.5980509532694631 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Gap from band 1 (0.36488998406249756) to band 2 (0.529921266047538), 36.88627785239544%
# Gap from band 3 (0.770619412085265) to band 4 (0.7774658096592912), 0.8844987960431514%
# Gap from band 4 (0.8788507684764247) to band 5 (0.8793010366338008), 0.05122062339182406%
# Gap from band 7 (1.1144668461713014) to band 8 (1.151973695379281), 3.30975805633262%
# Gap from band 13 (1.448374094260813) to band 14 (1.4504461930160093), 0.14296151881445984%
# Gap from band 14 (1.5348368247001694) to band 15 (1.576186710031307), 2.6582817435810013%
# total elapsed time for run: 15.289219379425049
# done

# %%
import matplotlib.pyplot as plt
import numpy as np 


fig, ax = plt.subplots()
x = range(len(tm_freqs))

for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([0, 0.8])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.5)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.5)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()
