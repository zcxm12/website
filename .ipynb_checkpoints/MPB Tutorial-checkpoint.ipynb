# %%
import math
import meep as mp
from meep import mpb

# %% [markdown]
# 首先指定模擬的參數和幾何形狀，然後告訴它運行並給我們輸出。
# 每個 k 點計算多少條帶（本徵態）。默認為 1，太小；讓我們將其設置為更大的值：

# %%
num_bands = 8#

# %% [markdown]
# 計算波段的 k 點集（布洛赫波向量）
# 設置在方格的不可約布里淵區的角上

# %%
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(0.5),       # X
            mp.Vector3(0.5, 0.5),  # M
            mp.Vector3()]          # Gamma

# %% [markdown]
# 計算許多中間 k 點的能帶，以便我們看到連續能帶結構。
# 可以調用 pymeep 提供的函數之一來植入，而不是手動指定

# %%
k_points = mp.interpolate(4, k_points)

# %% [markdown]
# 每對連續點之間線性插值四個新點。
# 它將顯示新列表中的所有 16 個點

# %%
[mp.Vector3(0, 0, 0), mp.Vector3(0.1, 0.0, 0.0), mp.Vector3(0.2, 0.0, 0.0), mp.Vector3(0.3, 0.0, 0.0), 
 mp.Vector3(0.4, 0.0, 0.0), mp.Vector3(0.5, 0, 0), mp.Vector3(0.5, 0.1, 0.0), mp.Vector3(0.5, 0.2, 0.0), 
 mp.Vector3(0.5, 0.3, 0.0), mp.Vector3(0.5, 0.4, 0.0), mp.Vector3(0.5, 0.5, 0), mp.Vector3(0.4, 0.4, 0.0), 
 mp.Vector3(0.3, 0.3, 0.0), mp.Vector3(0.2, 0.2, 0.0), mp.Vector3(0.1, 0.1, 0.0), mp.Vector3(0, 0, 0)]
# Out:
# [Vector3<0.0, 0.0, 0.0>,
#  Vector3<0.1, 0.0, 0.0>,
#  Vector3<0.2, 0.0, 0.0>,
#  Vector3<0.3, 0.0, 0.0>,
#  Vector3<0.4, 0.0, 0.0>,
#  Vector3<0.5, 0.0, 0.0>,
#  Vector3<0.5, 0.1, 0.0>,
#  Vector3<0.5, 0.2, 0.0>,
#  Vector3<0.5, 0.3, 0.0>,
#  Vector3<0.5, 0.4, 0.0>,
#  Vector3<0.5, 0.5, 0.0>,
#  Vector3<0.4, 0.4, 0.0>,
#  Vector3<0.3, 0.3, 0.0>,
#  Vector3<0.2, 0.2, 0.0>,
#  Vector3<0.1, 0.1, 0.0>,
#  Vector3<0.0, 0.0, 0.0>]

# %% [markdown]
# 設置系統的幾何形狀
# 想要一個方形晶格的棒，所以我們在原點放置一個電介質圓柱體：
# radius值為 0.2 其軸的長度無窮大 center是原點 epsilon是 12

# %%
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]

# %% [markdown]
# 幾何對像都是三維的，但由於我們正在進行二維模擬，重要的是XY平面 (z=0)
# geometry_lattice參數控制 meep.Lattice：維度設置為大小為 0，這會降低系統的維度。

# %%
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1))

# %%
resolution = 32

# %% [markdown]
# 創建一個ModeSolver對象，將我們設置的所有參數傳遞給構造函數。

# %%
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)

# %% [markdown]
# 計算能帶結構
# 由於這是一個二維計算，我們希望將波段分成 TE 和 TM 偏振模式，我們通過調用ms.run_te()和來做到這一點

# %%
#print_heading("Square lattice of rods: TE bands")
ms.run_te()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0
change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.566341472902691 (0.00081791% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.566296059223562 (0.000815866% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 5.566250320972846 (0.000821703% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 5.566203862442916 (0.00083465% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 5.566156307589252 (0.000854353% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 5.566107285936622 (0.000880713% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.566056426278942 (0.000913743% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.566003358134894 (0.000953429% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 5.565947721917592 (0.000999577% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 5.565889189200363 (0.00105163% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 5.565827494048979 (0.00110846% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 5.565762474562664 (0.0011682% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 5.565694120006174 (0.00122813% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 5.565622613497016 (0.00128478% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.565548355223426 (0.00133424% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.565471950730045 (0.00137282% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.565394156796156 (0.00139781% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.565315792927974 (0.00140807% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.565237641537023 (0.00140427% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.565160364524948 (0.00138858% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.565084455254986 (0.00136402% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.565010229409918 (0.00133379% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.564937845605258 (0.0013007% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.564867341705579 (0.00126694% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.564798674422246 (0.00123395% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.564731754270221 (0.00120257% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.564666472373489 (0.00117314% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.564602718663458 (0.00114569% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.564540392639095 (0.00112005% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.564479408450984 (0.00109595% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.564419696071974 (0.0010731% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.564361200043526 (0.00105126% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.56430387693352 (0.00103019% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.564247692306598 (0.00100974% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 5.564192617733777 (0.000989799% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 5.564138628162931 (0.000970308% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 5.564085699825847 (0.000951245% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.564033808758317 (0.000932612% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.56398292994158 (0.000914427% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.563933037025873 (0.000896716% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.563884102563261 (0.000879498% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 5.563836098651837 (0.000862781% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 5.563788997877102 (0.000846556% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 5.563742774426582 (0.000830794% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 5.563697405250913 (0.000815447% change)
#     resetting CG direction...
#     large trace change predicted (0.200629%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 5.552423263810791 (0.202843% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 5.545137467581171 (0.131304% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 5.542644613750529 (0.0449658% change)
#     linmin: converged after 4 iterations.
#     iteration   73: trace = 5.541072660377224 (0.0283651% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 5.540754803718874 (0.00573654% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 5.540661073039995 (0.00169167% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 5.540631586319864 (0.000532189% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 5.540611243476441 (0.000367158% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 5.540591624714147 (0.000354091% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 5.540580869919845 (0.000194109% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 5.540569641751664 (0.000202653% change)
#     linmin: converged after 3 iterations.
#     iteration   81: trace = 5.54055583996279 (0.000249104% change)
#     linmin: converged after 3 iterations.
#     iteration   82: trace = 5.540531764586827 (0.000434531% change)
#     linmin: converged after 3 iterations.
#     iteration   83: trace = 5.540510249305235 (0.000388326% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.540502892956759 (0.000132774% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 5.5405002025932 (4.85581e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   86: trace = 5.540498943660244 (2.27224e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   87: trace = 5.540498369326419 (1.03661e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   88: trace = 5.540497968716215 (7.23058e-06% change)
# Finished solving for bands 1 to 8 after 88 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.1, 0.0897333, 0.551138, 0.7616, 0.774682, 0.907199, 1.00188, 1.00357, 1.10209
# elapsed time for k point: 1.6415700912475586
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.514304570558254 (0.408189% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.503848436021177 (0.189798% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.50084308499234 (0.0546195% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 56.7505%)
#     iteration    4: trace = 5.499876232895317 (0.017578% change)
#     switching back to exact line minimization
#     iteration    5: trace = 5.499510158130532 (0.00665628% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.4454%)
#     iteration    6: trace = 5.499421989357091 (0.00160322% change)
#     switching back to exact line minimization
#     iteration    7: trace = 5.499394229719316 (0.000504775% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.499382472315625 (0.000213795% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.499378198095856 (7.77218e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.499376231290995 (3.57641e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.499375487239075 (1.35298e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.499375185558772 (5.48572e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:,
change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 5.552888787915237 (0.0083092% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 5.552531778248928 (0.00642947% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.552231631648159 (0.00540573% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.551957365134816 (0.00493987% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.551696722803994 (0.00469471% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 5.55145163176391 (0.0044148% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 5.551227864317086 (0.00403087% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 5.551026494356494 (0.00362755% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 5.550843730566968 (0.00329249% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 5.550675109594073 (0.0030378% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 5.550518008007325 (0.00283035% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.550371348139107 (0.00264231% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.55023440340196 (0.00246734% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.550106317454535 (0.00230778% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.549986301914496 (0.00216242% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.549873830455185 (0.00202654% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.549768688749797 (0.00189451% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.549671067533064 (0.00175903% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.549581513040534 (0.0016137% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.549500356206831 (0.00146241% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.549426894542167 (0.00132376% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.549359237988145 (0.00121917% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.549295200971059 (0.00115396% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.549233558886138 (0.00111082% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.549174534282429 (0.00106366% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.549118924331967 (0.00100214% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.549066820867175 (0.000938955% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.549017469391177 (0.000889369% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.548970267217664 (0.000850644% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.548925522918305 (0.000806356% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.548883923588385 (0.000749685% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 5.548845313603646 (0.000695818% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 5.548808330935964 (0.000666495% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 5.548771239042482 (0.000668468% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.548733143198582 (0.000686566% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.54869465759981 (0.000693595% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.548657342722231 (0.000672501% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.548622484210144 (0.000628235% change)
#     linmin: converged after 2 iterations.
#     iteration   66: trace = 5.54859064959575 (0.000573741% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 5.548562157272015 (0.000513507% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 5.548537373932227 (0.000446663% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 5.548516357141627 (0.000378781% change)
#     resetting CG direction...
#     large trace change predicted (0.00339405%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 5.548328033059605 (0.00339419% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 5.548230708166212 (0.00175415% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 5.548179286951016 (0.000926808% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 5.54815800856978 (0.000383521% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 5.548148168624747 (0.000177355% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 5.548144507567546 (6.5987e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 5.54814172279464 (5.01929e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 5.548138700933992 (5.44662e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 5.548134468727178 (7.62816e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 5.548128692960859 (0.000104103% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 5.548123652660038 (9.08469e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 5.548120922159764 (4.92149e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 5.548118985541342 (3.49058e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 5.548118257130372 (1.3129e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.548117906988212 (6.31101e-06% change)
# Finished solving for bands 2 to 8 after 84 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# elapsed time for k point: 1.9043025970458984
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.4968358657398373 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.4415884758347533 at Vector3<0.5, 0.0, 0.0> to 0.5931405182468185 at Vector3<0.5, 0.5, 0.0>
# Band 3 range: 0.5931535893551815 at Vector3<0.5, 0.5, 0.0> to 0.7732265681404649 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.679169013525543 at Vector3<0.5, 0.5, 0.0> to 0.8096891662050569 at Vector3<0.3, 0.3, 0.0>
# Band 5 range: 0.8241814492219044 at Vector3<0.5, 0.30000000000000004, 0.0> to 0.9229965317023906 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8819770936730285 at Vector3<0.5, 0.5, 0.0> to 1.0291597307273326 at Vector3<0.5, 0.0, 0.0>
# Band 7 range: 0.8819818143162784 at Vector3<0.5, 0.5, 0.0> to 1.0860733987651316 at Vector3<0.5, 0.0, 0.0>
# Band 8 range: 1.0878690871165269 at Vector3<0.5, 0.0, 0.0> to 1.1119174101928126 at Vector3<0.5, 0.5, 0.0>
# Gap from band 2 (0.5931405182468185) to band 3 (0.5931535893551815), 0.0022036876486622036%
# Gap from band 4 (0.8096891662050569) to band 5 (0.8241814492219044), 1.7739817192391767%
# Gap from band 7 (1.0860733987651316) to band 8 (1.0878690871165269), 0.16520109092646518%
# total elapsed time for run: 8.669906854629517
# done

# %% [markdown]
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# tefreqs:, k index, kx, ky, kz, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8
# k 點索引、k 分量和幅度以及頻帶的頻率，以逗號分隔的格式。
# tefreqs表示 TE 波段，“tmfreqs”表示 TM 波段

# %%
ms.run_tm(mpb.output_efield_z)
ms.run_te(mpb.output_at_kpoint(mp.Vector3(0.5), mpb.output_hfield_z, mpb.output_dpwr))
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.04899477958679199
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 10 iterations.
#     iteration    1: trace = 12.78805573817265 (195.295% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 5.044652365377109 (86.845% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.500287920135191 (11.4063% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.407924214065361 (2.07368% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.38711939285152 (0.473103% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.38157597672173 (0.126437% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.378904693589405 (0.0609849% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.377592483319773 (0.0299711% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.376869641031234 (0.0165137% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.375958576603105 (0.0208176% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 4.374903458391437 (0.0241146% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 4.374076876463316 (0.0188955% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 4.373792683309868 (0.00649743% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.3737320750568 (0.00138572% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.373723688820172 (0.000191741% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.373722708626953 (2.2411e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.373722454257473 (5.81586e-06% change)
# Finished solving for bands 2 to 8 after 17 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.3400712013244629
# Outputting fields to e.k01.b01.z.tm.h5...
# Outputting fields to e.k01.b02.z.tm.h5...
# Outputting fields to e.k01.b03.z.tm.h5...
# Outputting fields to e.k01.b04.z.tm.h5...
# Outputting fields to e.k01.b05.z.tm.h5...
# Outputting fields to e.k01.b06.z.tm.h5...
# Outputting fields to e.k01.b07.z.tm.h5...
# Outputting fields to e.k01.b08.z.tm.h5...
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.374742355214483 (0.779546% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.355235188634254 (0.446901% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.340001186630586 (0.350399% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.321196897630188 (0.434219% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.306200947136041 (0.347636% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.298326834555455 (0.183023% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 4.294710595923707 (0.0841667% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 4.292522409658823 (0.0509637% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 4.291431497470538 (0.0254175% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.291080815541191 (0.00817201% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.290981211700147 (0.00232121% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.290925928533003 (0.00128837% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.290895766890413 (0.000702919% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.290876133680101 (0.000457556% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 59.0867%)
#     iteration   15: trace = 4.290865184792962 (0.000255167% change)
#     iteration   16: trace = 4.290859790200055 (0.000125723% change)
#     switching back to exact line minimization
#     iteration   17: trace = 4.290857828575002 (4.57164e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.290857486555742 (7.97088e-06% change)
# Finished solving for bands 1 to 8 after 18 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.1, 0.0643671, 0.518896, 0.552617, 0.579095, 0.812721, 0.852958, 0.941428, 1.04995
# elapsed time for k point: 0.29842662811279297
# Outputting fields to e.k02.b01.z.tm.h5...
# Outputting fields to e.k02.b02.z.tm.h5...
# Outputting fields to e.k02.b03.z.tm.h5...
# Outputting fields to e.k02.b04.z.tm.h5...
# Outputting fields to e.k02.b05.z.tm.h5...
# Outputting fields to e.k02.b06.z.tm.h5...
# Outputting fields to e.k02.b07.z.tm.h5...
# Outputting fields to e.k02.b08.z.tm.h5...
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.213075597278083 (0.515751% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.209107644320753 (0.0942262% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.208518930506713 (0.0139876% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.208361683834328 (0.00373646% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.208319532002708 (0.00100163% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.208309587812753 (0.000236299% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.208308120218636 (3.48737e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.208307969849537 (3.57315e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.2, 0.126061, 0.48795, 0.553991, 0.610359, 0.812384, 0.849484, 0.912816, 1.02959
# elapsed time for k point: 0.1941547393798828
# Outputting fields to e.k03.b01.z.tm.h5...
# Outputting fields to e.k03.b02.z.tm.h5...
# Outputting fields to e.k03.b03.z.tm.h5...
# Outputting fields to e.k03.b04.z.tm.h5...
# Outputting fields to e.k03.b05.z.tm.h5...
# Outputting fields to e.k03.b06.z.tm.h5...
# Outputting fields to e.k03.b07.z.tm.h5...
# Outputting fields to e.k03.b08.z.tm.h5...
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.153950497664935 (0.446636% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.150919161712114 (0.0730014% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.150508698489219 (0.00988898% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.150451669102559 (0.00137404% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.150445324052573 (0.000152876% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.150444375598905 (2.28519e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.150444119700321 (6.16557e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.3, 0.181523, 0.45665, 0.555709, 0.644685, 0.802314, 0.845326, 0.880698, 1.025
# elapsed time for k point: 0.138505220413208
# Outputting fields to e.k04.b01.z.tm.h5...
# Outputting fields to e.k04.b02.z.tm.h5...
# Outputting fields to e.k04.b03.z.tm.h5...
# Outputting fields to e.k04.b04.z.tm.h5...
# Outputting fields to e.k04.b05.z.tm.h5...
# Outputting fields to e.k04.b06.z.tm.h5...
# Outputting fields to e.k04.b07.z.tm.h5...
# Outputting fields to e.k04.b08.z.tm.h5...
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.123905399429191 (0.437377% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.120354157650915 (0.0861507% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.119752234768201 (0.0146096% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.119635301116344 (0.00283841% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.119609417531581 (0.0006283% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.11960169877702 (0.000187366% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.119598937194648 (6.70352e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.119598626300595 (7.54671e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.4, 0.224302, 0.429317, 0.557116, 0.682524, 0.772176, 0.842059, 0.865404, 1.0269
# elapsed time for k point: 0.21661758422851562
# Outputting fields to e.k05.b01.z.tm.h5...
# Outputting fields to e.k05.b02.z.tm.h5...
# Outputting fields to e.k05.b03.z.tm.h5...
# Outputting fields to e.k05.b04.z.tm.h5...
# Outputting fields to e.k05.b05.z.tm.h5...
# Outputting fields to e.k05.b06.z.tm.h5...
# Outputting fields to e.k05.b07.z.tm.h5...
# Outputting fields to e.k05.b08.z.tm.h5...
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.117165716042645 (0.467243% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.112183270677918 (0.12109% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.111188958937895 (0.0241826% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.110889430815072 (0.00728595% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.1108070424307 (0.00200417% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.110783677541599 (0.000568379% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.110777732782466 (0.000144614% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.110777279786336 (1.10197e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.110777245124082 (8.43204e-07% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.5, 0.241821, 0.417114, 0.557658, 0.713395, 0.741311, 0.84083, 0.862516, 1.02856
# elapsed time for k point: 0.19341087341308594
# Outputting fields to e.k06.b01.z.tm.h5...
# Outputting fields to e.k06.b02.z.tm.h5...
# Outputting fields to e.k06.b03.z.tm.h5...
# Outputting fields to e.k06.b04.z.tm.h5...
# Outputting fields to e.k06.b05.z.tm.h5...
# Outputting fields to e.k06.b06.z.tm.h5...
# Outputting fields to e.k06.b07.z.tm.h5...
# Outputting fields to e.k06.b08.z.tm.h5...
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.110059681367753 (0.89808% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.101196125277966 (0.215888% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.099627972088558 (0.0382438% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.099504340242942 (0.00301573% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.099491102149281 (0.00032292% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.099490015388341 (2.65097e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 66.3617%)
#     iteration    7: trace = 4.099489970449637 (1.0962e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, 0.5, 0.1, 0, 0.509902, 0.245235, 0.4236, 0.551085, 0.711571, 0.749855, 0.841982, 0.862609, 1.01714
# elapsed time for k point: 0.15303826332092285
# Outputting fields to e.k07.b01.z.tm.h5...
# Outputting fields to e.k07.b02.z.tm.h5...
# Outputting fields to e.k07.b03.z.tm.h5...
# Outputting fields to e.k07.b04.z.tm.h5...
# Outputting fields to e.k07.b05.z.tm.h5...
# Outputting fields to e.k07.b06.z.tm.h5...
# Outputting fields to e.k07.b07.z.tm.h5...
# Outputting fields to e.k07.b08.z.tm.h5...
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 67.49%)
#     iteration    1: trace = 4.085143988179796 (0.762375% change)
#     iteration    2: trace = 4.080120616208026 (0.123042% change)
#     iteration    3: trace = 4.079494204746106 (0.0153539% change)
#     iteration    4: trace = 4.079455646796386 (0.000945169% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.079453228426908 (5.92817e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.2722%)
#     iteration    6: trace = 4.079452946953421 (6.89978e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 8, 0.5, 0.2, 0, 0.538516, 0.25442, 0.441321, 0.535034, 0.706018, 0.772267, 0.845818, 0.862861, 0.989395
# elapsed time for k point: 0.08957982063293457
# Outputting fields to e.k08.b01.z.tm.h5...
# Outputting fields to e.k08.b02.z.tm.h5...
# Outputting fields to e.k08.b03.z.tm.h5...
# Outputting fields to e.k08.b04.z.tm.h5...
# Outputting fields to e.k08.b05.z.tm.h5...
# Outputting fields to e.k08.b06.z.tm.h5...
# Outputting fields to e.k08.b07.z.tm.h5...
# Outputting fields to e.k08.b08.z.tm.h5...
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.072737316303574 (0.634149% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.069415980125489 (0.0815837% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.068882805700349 (0.0131028% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.06877700533797 (0.00260027% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.068760921355551 (0.000395303% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.068759373723699 (3.80369e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.068759283088574 (2.22759e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 9, 0.5, 0.3, 0, 0.583095, 0.266397, 0.465222, 0.516482, 0.697068, 0.802974, 0.853388, 0.863228, 0.954203
# elapsed time for k point: 0.14996027946472168
# Outputting fields to e.k09.b01.z.tm.h5...
# Outputting fields to e.k09.b02.z.tm.h5...
# Outputting fields to e.k09.b03.z.tm.h5...
# Outputting fields to e.k09.b04.z.tm.h5...
# Outputting fields to e.k09.b05.z.tm.h5...
# Outputting fields to e.k09.b06.z.tm.h5...
# Outputting fields to e.k09.b07.z.tm.h5...
# Outputting fields to e.k09.b08.z.tm.h5...
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.080410536994166 (0.563622% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.077287254814368 (0.0765726% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.076189669319784 (0.0269231% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.075628846883982 (0.0137594% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.075534308234992 (0.00231964% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.075527487574776 (0.000167356% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.075526996409094 (1.20516e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.075526953552012 (1.05157e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 10, 0.5, 0.4, 0, 0.640312, 0.276774, 0.48701, 0.501823, 0.687264, 0.837704, 0.86397, 0.865932, 0.916273
# elapsed time for k point: 0.17192769050598145
# Outputting fields to e.k10.b01.z.tm.h5...
# Outputting fields to e.k10.b02.z.tm.h5...
# Outputting fields to e.k10.b03.z.tm.h5...
# Outputting fields to e.k10.b04.z.tm.h5...
# Outputting fields to e.k10.b05.z.tm.h5...
# Outputting fields to e.k10.b06.z.tm.h5...
# Outputting fields to e.k10.b07.z.tm.h5...
# Outputting fields to e.k10.b08.z.tm.h5...
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.109442394203863 (0.504919% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.105340119416493 (0.0998754% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.100310511948726 (0.122589% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.093804080725421 (0.158807% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 4.092241827075007 (0.0381687% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.092157129374288 (0.00206974% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.092151257996867 (0.000143479% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.092150667100219 (1.44398e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.092150601322292 (1.60742e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 11, 0.5, 0.5, 0, 0.707107, 0.280948, 0.496196, 0.496197, 0.682617, 0.859474, 0.878316, 0.878316, 0.879351
# elapsed time for k point: 0.20673036575317383
# Outputting fields to e.k11.b01.z.tm.h5...
# Outputting fields to e.k11.b02.z.tm.h5...
# Outputting fields to e.k11.b03.z.tm.h5...
# Outputting fields to e.k11.b04.z.tm.h5...
# Outputting fields to e.k11.b05.z.tm.h5...
# Outputting fields to e.k11.b06.z.tm.h5...
# Outputting fields to e.k11.b07.z.tm.h5...
# Outputting fields to e.k11.b08.z.tm.h5...
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.126323580077027 (1.11567% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 4.089033099217471 (0.907824% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 4.06056172585645 (0.698719% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.050052747488004 (0.259141% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.047169207001508 (0.071223% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.046718796939653 (0.0111296% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.046656935610446 (0.00152869% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.046652820456807 (0.000101693% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.046652399651329 (1.03989e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.046652261454691 (3.41509e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 12, 0.4, 0.4, 0, 0.565685, 0.27141, 0.485365, 0.501693, 0.689111, 0.830636, 0.844978, 0.893706, 0.898991
# elapsed time for k point: 0.39484167098999023
# Outputting fields to e.k12.b01.z.tm.h5...
# Outputting fields to e.k12.b02.z.tm.h5...
# Outputting fields to e.k12.b03.z.tm.h5...
# Outputting fields to e.k12.b04.z.tm.h5...
# Outputting fields to e.k12.b05.z.tm.h5...
# Outputting fields to e.k12.b06.z.tm.h5...
# Outputting fields to e.k12.b07.z.tm.h5...
# Outputting fields to e.k12.b08.z.tm.h5...
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.050145868722081 (0.874825% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.6346%)
#     iteration    2: trace = 4.045158295823572 (0.123221% change)
#     switching back to exact line minimization
#     iteration    3: trace = 4.044571707726017 (0.014502% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.044525079707769 (0.00115286% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.044514974498805 (0.000249849% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.1399%)
#     iteration    6: trace = 4.044513398013455 (3.89784e-05% change)
#     switching back to exact line minimization
#     iteration    7: trace = 4.044513255723025 (3.51811e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.236529, 0.473888, 0.515941, 0.679199, 0.819377, 0.829518, 0.897603, 0.933446
# elapsed time for k point: 0.29714155197143555
# Outputting fields to e.k13.b01.z.tm.h5...
# Outputting fields to e.k13.b02.z.tm.h5...
# Outputting fields to e.k13.b03.z.tm.h5...
# Outputting fields to e.k13.b04.z.tm.h5...
# Outputting fields to e.k13.b05.z.tm.h5...
# Outputting fields to e.k13.b06.z.tm.h5...
# Outputting fields to e.k13.b07.z.tm.h5...
# Outputting fields to e.k13.b08.z.tm.h5...
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.118864788208757 (0.847797% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.114001813615838 (0.118136% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.113487122083887 (0.0125115% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.113430168670157 (0.00138456% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.113416440840478 (0.000333732% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.113415367538774 (2.60927e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.113415271018478 (2.34648e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 14, 0.2, 0.2, 0, 0.282843, 0.172884, 0.482973, 0.533242, 0.640233, 0.819202, 0.838111, 0.910409, 0.976551
# elapsed time for k point: 0.24178838729858398
# Outputting fields to e.k14.b01.z.tm.h5...
# Outputting fields to e.k14.b02.z.tm.h5...
# Outputting fields to e.k14.b03.z.tm.h5...
# Outputting fields to e.k14.b04.z.tm.h5...
# Outputting fields to e.k14.b05.z.tm.h5...
# Outputting fields to e.k14.b06.z.tm.h5...
# Outputting fields to e.k14.b07.z.tm.h5...
# Outputting fields to e.k14.b08.z.tm.h5...
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.250027210019413 (0.91784% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.617%)
#     iteration    2: trace = 4.242313584673143 (0.181661% change)
#     switching back to exact line minimization
#     iteration    3: trace = 4.241112607849205 (0.0283135% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.240834138611625 (0.00656616% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.240767212976181 (0.00157814% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.240753134882901 (0.000331971% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.240750096071682 (7.16574e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.240749691670978 (9.53607e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 15, 0.1, 0.1, 0, 0.141421, 0.0904174, 0.510404, 0.546943, 0.593803, 0.81373, 0.851132, 0.935551, 1.02882
# elapsed time for k point: 0.22182464599609375
# Outputting fields to e.k15.b01.z.tm.h5...
# Outputting fields to e.k15.b02.z.tm.h5...
# Outputting fields to e.k15.b03.z.tm.h5...
# Outputting fields to e.k15.b04.z.tm.h5...
# Outputting fields to e.k15.b05.z.tm.h5...
# Outputting fields to e.k15.b06.z.tm.h5...
# Outputting fields to e.k15.b07.z.tm.h5...
# Outputting fields to e.k15.b08.z.tm.h5...
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.407938964818472 (1.14495% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.390605904542783 (0.393998% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.386368824361528 (0.0965499% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.384519798480751 (0.0421628% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.382811016221957 (0.0389807% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 4.380356866557224 (0.0560106% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.377812268037348 (0.058108% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.375796100252696 (0.0460648% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 4.374248633379787 (0.0353705% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 4.373812424469191 (0.0099727% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.373736292752488 (0.00174064% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.373725631636528 (0.000243753% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.373723713508723 (4.38557e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.373723044357132 (1.52994e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.373722608363732 (9.96847e-06% change)
# Finished solving for bands 2 to 8 after 15 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.3647499084472656
# Outputting fields to e.k16.b01.z.tm.h5...
# Outputting fields to e.k16.b02.z.tm.h5...
# Outputting fields to e.k16.b03.z.tm.h5...
# Outputting fields to e.k16.b04.z.tm.h5...
# Outputting fields to e.k16.b05.z.tm.h5...
# Outputting fields to e.k16.b06.z.tm.h5...
# Outputting fields to e.k16.b07.z.tm.h5...
# Outputting fields to e.k16.b08.z.tm.h5...
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28094795584045895 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.41711424941157077 at Vector3<0.5, 0.0, 0.0> to 0.5460267985070222 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4961974535699288 at Vector3<0.5, 0.5, 0.0> to 0.5576576363777928 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.5520955891162498 at Vector3<0.0, 0.0, 0.0> to 0.713395151752088 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.7413109658608312 at Vector3<0.5, 0.0, 0.0> to 0.8594741081096262 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.8295176174958703 at Vector3<0.3, 0.3, 0.0> to 0.8783155718493133 at Vector3<0.5, 0.5, 0.0>
# Band 7 range: 0.8625159058773569 at Vector3<0.5, 0.0, 0.0> to 0.9511074625732174 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8793510958411628 at Vector3<0.5, 0.5, 0.0> to 1.0825931586398507 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.28094795584045895) to band 2 (0.41711424941157077), 39.01265318380904%
# Gap from band 4 (0.713395151752088) to band 5 (0.7413109658608312), 3.838000510309437%
# total elapsed time for run: 4.657201528549194
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.031717777252197266
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 17.03031782496853 (193.764% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 7.51741174220946 (77.5054% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 6.424006623054559 (15.6857% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.028859650135597 (6.34628% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.854035222107161 (2.94246% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.766332981682961 (1.50946% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.711637797342635 (0.953046% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.661962168569517 (0.873525% change)
#     linmin: converged after 5 iterations.
#     iteration    9: trace = 5.615044925299137 (0.832087% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.583000225487756 (0.572327% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.566707763648783 (0.292249% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.559151312367668 (0.135836% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.556002964712293 (0.0566496% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.554654345949925 (0.0242761% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 5.553971016500664 (0.0123027% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 5.553496518522379 (0.00854377% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 5.55305080184946 (0.0080262% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 5.552427041981575 (0.0112334% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 5.551460455032354 (0.0174099% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.550297625944987 (0.0209486% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.54938905329486 (0.0163711% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.548869451706513 (0.00936366% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 5.548585184748925 (0.0051231% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 5.548415791010353 (0.00305296% change)
#     linmin: converged after 4 iterations.
#     iteration   25: trace = 5.548294903905028 (0.00217879% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 5.548212325574797 (0.00148837% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 5.548165574878724 (0.00084263% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 5.548141785092911 (0.000428787% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 5.548129763701464 (0.000216674% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 5.5481241805688 (0.000100631% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 5.548121658148501 (4.54644e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 5.548120405556364 (2.25769e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 5.548119822938522 (1.05012e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 5.548119534491928 (5.199e-06% change)
# Finished solving for bands 2 to 8 after 34 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# elapsed time for k point: 1.1676125526428223
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.581243496357172 (0.239607% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.573788651159036 (0.133659% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.571425799424402 (0.0424012% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.569947428508321 (0.0265384% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.569097016740512 (0.015269% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.568409119625483 (0.0123528% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.567978732729797 (0.00772938% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.567693156063485 (0.00512904% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.567554369804975 (0.00249274% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 5.56746483317515 (0.0016082% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.567426375565146 (0.000690759% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.567411221881072 (0.000272185% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.56740530703378 (0.000106241% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.567403508631124 (3.23024e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.567402233993818 (2.28946e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 5.567401008433165 (2.20132e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.56739934786817 (2.98266e-05% change)
#     large trace change predicted (7.09527e-05%)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.567395396151815 (7.09796e-05% change)
#     large trace change predicted (0.000696426%)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 5.56735720680251 (0.000685949% change)
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration   20: trace = 5.566998458187376 (0.00644399% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.5669641901524 (0.000615559% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.566934309218512 (0.000536756% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 5.566907337169212 (0.000484506% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 5.566882365789368 (0.000448569% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.566858820334274 (0.000422957% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.566836318456659 (0.000404212% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 5.566814593604493 (0.000390256% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 5.566793452163417 (0.000379777% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 5.566772748217979 (0.000371919% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.566752367893981 (0.000366107% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.566732219144197 (0.000361949% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.566712224761602 (0.000359177% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 5.566692317385598 (0.000357615% change)
#     linmin: converged after 4 iterations.
#     iteration   34: trace = 5.566672435791476 (0.000357153% change)
#     linmin: converged after 4 iterations.
#     iteration   35: trace = 5.566652522044587 (0.000357732% change)
#     linmin: converged after 4 iterations.
#     iteration   36: trace = 5.566632519269404 (0.000359333% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 5.566612369883185 (0.000361968% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 5.566592014205303 (0.000365675% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.566571389391924 (0.000370511% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.566550428671876 (0.000376547% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.566529060879653 (0.000383861% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.566507210299147 (0.000392536% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.566484796849871 (0.000402649% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.566461736666689 (0.000414269% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.566437943144262 (0.000427445% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.566413328536283 (0.000442198% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.56638780621271 (0.000458507% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.566361293677624 (0.000476298% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.566333716425688 (0.000495428% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.566305012652298 (0.000515669% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.5662751387172 (0.000536694% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.566244075085849 (0.00055807% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.566211832243693 (0.000579258% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.566178455832353 (0.000599627% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.566144030064111 (0.000618483% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.566108678432549 (0.000635121% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.566072560948282 (0.000648884% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.566035867624478 (0.000659234% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 5.565998808640456 (0.000665808% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 5.56596160232874 (0.000668459% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 5.565924462617238 (0.000667267% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.565887587637743 (0.000662515% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.565851150866974 (0.000654647% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.56581529554387 (0.000644204% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.565780132431527 (0.000631771% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 5.565745740458729 (0.00061792% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 5.565712169478866 (0.000603173% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 5.565679444317443 (0.00058798% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 5.56564756937472 (0.000572707% change)
#     resetting CG direction...
#     large trace change predicted (0.185396%)
#     linmin: converged after 3 iterations.
#     iteration   70: trace = 5.554995584657382 (0.191571% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 5.544873202302508 (0.182387% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 5.542386225215019 (0.0448619% change)
#     linmin: converged after 3 iterations.
#     iteration   73: trace = 5.541733491435672 (0.0117778% change)
#     linmin: converged after 3 iterations.
#     iteration   74: trace = 5.541482049694006 (0.00453734% change)
#     linmin: converged after 3 iterations.
#     iteration   75: trace = 5.541354309932291 (0.00230518% change)
#     linmin: converged after 3 iterations.
#     iteration   76: trace = 5.541265320810558 (0.00160592% change)
#     linmin: converged after 3 iterations.
#     iteration   77: trace = 5.541166366273998 (0.00178579% change)
#     linmin: converged after 3 iterations.
#     iteration   78: trace = 5.540981111126931 (0.00334331% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 5.540776029764155 (0.00370124% change)
#     linmin: converged after 3 iterations.
#     iteration   80: trace = 5.540694804756885 (0.00146596% change)
#     linmin: converged after 3 iterations.
#     iteration   81: trace = 5.540632202254153 (0.00112987% change)
#     linmin: converged after 3 iterations.
#     iteration   82: trace = 5.540583649698696 (0.000876304% change)
#     linmin: converged after 3 iterations.
#     iteration   83: trace = 5.540551918622385 (0.000572704% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.540525548247136 (0.000475953% change)
#     linmin: converged after 3 iterations.
#     iteration   85: trace = 5.54051125077892 (0.000258053% change)
#     linmin: converged after 2 iterations.
#     iteration   86: trace = 5.540504483336287 (0.000122145% change)
#     linmin: converged after 2 iterations.
#     iteration   87: trace = 5.540501024834559 (6.24222e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   88: trace = 5.540499233586191 (3.23301e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   89: trace = 5.540498168922585 (1.9216e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   90: trace = 5.540497595754971 (1.03451e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   91: trace = 5.540497350063671 (4.43446e-06% change)
# Finished solving for bands 1 to 8 after 91 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.1, 0.0897332, 0.551138, 0.7616, 0.774682, 0.907199, 1.00188, 1.00357, 1.10209
# elapsed time for k point: 3.2226200103759766
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.514298634777768 (0.409008% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.503851969010018 (0.189626% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.500841715505976 (0.0547085% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.499875921990943 (0.0175587% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.499510000877811 (0.00665348% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.499421908224665 (0.00160184% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.499394181484409 (0.000504177% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.499382430082401 (0.000213686% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.499378166015333 (7.75372e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.499376207444278 (3.56144e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.499375451548499 (1.37451e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.499375151410028 (5.45768e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.2, 0.178692, 0.544896, 0.728534, 0.778528, 0.880244, 1.00699, 1.01696, 1.10027
# elapsed time for k point: 0.5734906196594238
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.496159356118666 (0.277878% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.48950989649993 (0.121057% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.487055193737065 (0.0447262% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.48620426602027 (0.0155091% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.485738750458319 (0.00848556% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.485576138743687 (0.00296431% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.485498661287201 (0.0014124% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.485469816910865 (0.000525831% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.485462057362738 (0.000141457% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.485459952642135 (3.83691e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.485459323192048 (1.14749e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.485459173741867 (2.72448e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.3, 0.265798, 0.528176, 0.685449, 0.783377, 0.860714, 1.01515, 1.03843, 1.09664
# elapsed time for k point: 0.48340368270874023
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.518166696729534 (0.240354% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.511317094252455 (0.124205% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.507827482666276 (0.0633373% change)
#     linmin: converged after 4 iterations.
# ...
#     iteration    4: trace = 5.207408517433346 (0.0226123% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.206822746092254 (0.0112494% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.206658313133609 (0.00315808% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.206604933763654 (0.00102522% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.206579361533177 (0.000491151% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.206571414707819 (0.000152631% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.206567830690614 (6.88364e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.206566745491617 (2.08429e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.206566438482263 (5.89658e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:,
change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 5.551227770921701 (0.00403086% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 5.551026402657318 (0.00362752% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 5.55084364125945 (0.00329244% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 5.550675022092554 (0.00303777% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 5.550517921277973 (0.00283034% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.550371262083594 (0.0026423% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.55023431897024 (0.00246731% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.550106235487108 (0.00230774% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.549986222365762 (0.00216238% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.549873752914805 (0.0020265% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.54976861336226 (0.00189447% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.549670995038099 (0.00175898% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.549581443973054 (0.00161364% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.549500290349204 (0.00146235% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.549426831210508 (0.00132372% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.54935917662392 (0.00121913% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.54929514136647 (0.00115393% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.549233500993989 (0.00111078% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.549174477974507 (0.00106363% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.549118869415496 (0.00100211% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.549066767282239 (0.000938931% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.54901741729693 (0.000889342% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.548970216871412 (0.000850612% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.548925474463921 (0.000806322% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.548883876923648 (0.000749653% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 5.548845268402178 (0.000695791% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 5.548808286750594 (0.000666477% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 5.548771195439784 (0.000668458% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.548733099977039 (0.000686559% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.548694615026101 (0.000693583% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.548657301492403 (0.000672476% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.548622445076259 (0.000628197% change)
#     linmin: converged after 2 iterations.
#     iteration   66: trace = 5.548590613032754 (0.000573694% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 5.54856212341522 (0.000513458% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 5.548537342659483 (0.000446617% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 5.548516328133186 (0.000378741% change)
#     resetting CG direction...
#     large trace change predicted (0.0033937%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 5.548328023998694 (0.00339383% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 5.548230700811614 (0.00175411% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 5.548179283107774 (0.000926745% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 5.548158006559518 (0.000383488% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 5.548148167345634 (0.000177342% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 5.548144506492598 (6.59834e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 5.548141721875703 (5.01901e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 5.548138700074022 (5.44651e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 5.548134467998324 (7.62792e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 5.548128692633666 (0.000104096% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 5.548123652481383 (9.08442e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 5.548120921952913 (4.92154e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 5.548118985423629 (3.49042e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 5.548118257112806 (1.31272e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.548117906990402 (6.31065e-06% change)
# Finished solving for bands 2 to 8 after 84 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# elapsed time for k point: 4.276894569396973
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.4968358657398502 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.44158847583466665 at Vector3<0.5, 0.0, 0.0> to 0.5931405182468832 at Vector3<0.5, 0.5, 0.0>
# Band 3 range: 0.5931535893552249 at Vector3<0.5, 0.5, 0.0> to 0.7732265678573129 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.6791690135255468 at Vector3<0.5, 0.5, 0.0> to 0.8096891662050557 at Vector3<0.3, 0.3, 0.0>
# Band 5 range: 0.8241814492203713 at Vector3<0.5, 0.30000000000000004, 0.0> to 0.9229965285145569 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8819770936730649 at Vector3<0.5, 0.5, 0.0> to 1.0291597307277085 at Vector3<0.5, 0.0, 0.0>
# Band 7 range: 0.881981814316293 at Vector3<0.5, 0.5, 0.0> to 1.0860733987624893 at Vector3<0.5, 0.0, 0.0>
# Band 8 range: 1.0878690871395542 at Vector3<0.5, 0.0, 0.0> to 1.111917410200916 at Vector3<0.5, 0.5, 0.0>
# Gap from band 2 (0.5931405182468832) to band 3 (0.5931535893552249), 0.002203687645068243%
# Gap from band 4 (0.8096891662050557) to band 5 (0.8241814492203713), 1.7739817190533265%
# Gap from band 7 (1.0860733987624893) to band 8 (1.0878690871395542), 0.1652010932864955%
# total elapsed time for run: 18.157875061035156
# done

# %%
ms.geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                                 basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
                                 basis2=mp.Vector3(math.sqrt(3) / 2, -0.5))

# %%
ms.k_points = [mp.Vector3(),               # Gamma
              mp.Vector3(y=0.5),          # M
              mp.Vector3(-1 / 3, 1 / 3),  # K
              mp.Vector3()]               # Gamma

ms.k_points = mp.interpolate(4, ms.k_points)

# %%
ms.run_tm()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0
-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.28326649783832 (1.90496e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.222593, 0.476537, 0.539917, 0.715636, 0.806516, 0.856013, 0.929969, 0.977199
# elapsed time for k point: 0.17784357070922852
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.420128758717961 (0.818879% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.412260720018812 (0.178163% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.410633722834067 (0.0368813% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.410197903137275 (0.0098816% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.410114422161129 (0.00189293% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.410103888122515 (0.000238861% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.410102421564559 (3.32545e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.410102293673313 (2.89996e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.15856, 0.501245, 0.552927, 0.666818, 0.82116, 0.846938, 0.963589, 1.03113
# elapsed time for k point: 0.1894056797027588
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.563329249693654 (1.02702% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.544560536322283 (0.412142% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.537741040007315 (0.150171% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.535260974244445 (0.0546691% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.534595978095718 (0.0146639% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.534531476630522 (0.00142244% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.534520999897531 (0.000231044% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.53451865835962 (5.16381e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.53451783144381 (1.8236e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.534517685413176 (3.22042e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0819275, 0.534465, 0.558896, 0.622523, 0.832982, 0.840137, 0.98638, 1.08149
# elapsed time for k point: 0.3097996711730957
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.620880146122095 (1.44427% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.585845924982479 (0.761057% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.579348343661806 (0.141788% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.578210977834427 (0.0248399% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.577956199330377 (0.00556518% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 4.577915094931051 (0.000897881% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.577900179005661 (0.000325824% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.577895723328433 (9.73302e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.577894738437014 (2.15141e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.577894647486888 (1.98672e-06% change)
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.4093918800354004
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27469022601674825 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4453310810690979 at Vector3<0.0, 0.5, 0.0> to 0.5605181433629043 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4902389149689681 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607973872001 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960879458024 at Vector3<0.0, 0.0, 0.0> to 0.7907195975678293 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908320764965167 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511194377583 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948534061817 at Vector3<0.0, 0.0, 0.0> to 0.8672009266363934 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8691349976047854 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291062889729 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210416 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.09831836412307 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27469022601674825) to band 2 (0.4453310810690979), 47.39883483253771%
# Gap from band 3 (0.5605607973872001) to band 4 (0.5932960879458024), 5.6740642578312235%
# Gap from band 4 (0.7907195975678293) to band 5 (0.7908320764965167), 0.01422387020694968%
# Gap from band 5 (0.8374511194377583) to band 6 (0.8375948534061817), 0.017161793855644536%
# Gap from band 6 (0.8672009266363934) to band 7 (0.8691349976047854), 0.2227761277515789%
# total elapsed time for run: 4.620702743530273
# done

# %%
def first_tm_gap(r):
    ms.geometry = [mp.Cylinder(r, material=mp.Medium(epsilon=12))]
    ms.run_tm()
    return -1 * ms.retrieve_gap(1) # return the gap from TM band 1 to TM band 2

# %%
ms.num_bands = 2

# %%
ms.mesh_size = 7

# %%
from scipy.optimize import minimize_scalar

result = minimize_scalar(first_tm_gap, method='bounded', bounds=[0.1, 0.5], options={'xatol': 0.1})
print("radius at maximum: {}".format(result.x))
print("gap size at maximum: {}".format(result.fun * -1))
# Out:
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 7.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.252786, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.033968448638916016
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2
# Solving for bands 2 to 2...
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 1.008578928157514 (198.165% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 0.3132404719376058 (105.209% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.2402683892399369 (26.3671% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 0.2197764211087184 (8.90868% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 69.2718%)
#     iteration    5: trace = 0.2171580792099012 (1.19851% change)
#     iteration    6: trace = 0.2169417345404297 (0.0996751% change)
#     iteration    7: trace = 0.2169071620457781 (0.0159376% change)
#     iteration    8: trace = 0.216905690092643 (0.000678612% change)
#     iteration    9: trace = 0.2169053971240017 (0.000135067% change)
#     iteration   10: trace = 0.216905351168308 (2.1187e-05% change)
#     iteration   11: trace = 0.2169053497174451 (6.68892e-07% change)
# Finished solving for bands 2 to 2 after 11 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.465731
# elapsed time for k point: 0.03536844253540039
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 0.216640719810376 (6.39735% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.8272%)
#     iteration    2: trace = 0.2145048675951103 (0.99078% change)
#     iteration    3: trace = 0.2140220304189338 (0.225347% change)
#     iteration    4: trace = 0.2124979701771513 (0.714649% change)
#     iteration    5: trace = 0.2112887255368014 (0.570686% change)
#     iteration    6: trace = 0.211010127102019 (0.131944% change)
#     iteration    7: trace = 0.2109275688669441 (0.0391329% change)
#     iteration    8: trace = 0.2109221723203271 (0.00255852% change)
#     iteration    9: trace = 0.2109215369324914 (0.000301243% change)
#     iteration   10: trace = 0.2109204972742416 (0.000492914% change)
#     iteration   11: trace = 0.2109192829081613 (0.000575748% change)
#     iteration   12: trace = 0.210918984764405 (0.000141355% change)
#     iteration   13: trace = 0.2109189561060068 (1.35874e-05% change)
#     iteration   14: trace = 0.2109189544249693 (7.97006e-07% change)
# Finished solving for bands 1 to 2 after 14 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0608853, 0.455205
# elapsed time for k point: 0.03510236740112305
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.2013831782109853 (6.56277% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.4443%)
#     iteration    2: trace = 0.2005354062077956 (0.421863% change)
#     iteration    3: trace = 0.2005071066943646 (0.014113% change)
#     iteration    4: trace = 0.2005060352228075 (0.000534382% change)
#     iteration    5: trace = 0.2005060104674778 (1.23464e-05% change)
#     iteration    6: trace = 0.2005060088506463 (8.06376e-07% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.119259, 0.431605
# elapsed time for k point: 0.015221118927001953
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.1932096630017833 (5.92888% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 74.5055%)
#     iteration    2: trace = 0.1928900818358021 (0.165543% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.1928761191036528 (0.00723896% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 67.264%)
#     iteration    4: trace = 0.1928756113336998 (0.000263263% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.192875598439346 (6.68532e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.17191, 0.404132
# elapsed time for k point: 0.019186019897460938
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.1892641981509536 (6.11827% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 64.9752%)
#     iteration    2: trace = 0.1890123449093463 (0.133158% change)
#     iteration    3: trace = 0.1890005529292272 (0.00623893% change)
#     iteration    4: trace = 0.189000184020059 (0.00019519% change)
#     iteration    5: trace = 0.1890001768714244 (3.78234e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.213092, 0.378935
# elapsed time for k point: 0.023287534713745117
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.1881494864090495 (6.4211% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.1879067876202601 (0.129076% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.211%)
#     iteration    3: trace = 0.1878959528960669 (0.00576618% change)
#     iteration    4: trace = 0.1878955815080897 (0.000197656% change)
#     iteration    5: trace = 0.1878955757571371 (3.06072e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.230411, 0.36716
# elapsed time for k point: 0.01828742027282715
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 76.6192%)
#     iteration    1: trace = 0.1896233340673656 (0.417555% change)
#     iteration    2: trace = 0.1895967335365262 (0.0140291% change)
#     iteration    3: trace = 0.1895957890294789 (0.000498168% change)
#     iteration    4: trace = 0.1895957770733177 (6.30613e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.231338, 0.368888
# elapsed time for k point: 0.014170408248901367
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 72.6013%)
#     iteration    1: trace = 0.1945681367419125 (0.520565% change)
#     iteration    2: trace = 0.194533642457152 (0.0177302% change)
#     iteration    3: trace = 0.1945322846993202 (0.000697958% change)
#     iteration    4: trace = 0.1945322651585362 (1.0045e-05% change)
#     iteration    5: trace = 0.1945322646038878 (2.85119e-07% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.233922, 0.373916
# elapsed time for k point: 0.01875901222229004
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 68.2766%)
#     iteration    1: trace = 0.2022473490698355 (0.736019% change)
#     iteration    2: trace = 0.2021944725461809 (0.0261479% change)
#     iteration    3: trace = 0.2021922338994665 (0.00110718% change)
#     iteration    4: trace = 0.2021921954750298 (1.90039e-05% change)
#     iteration    5: trace = 0.2021921941931855 (6.33973e-07% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.237544, 0.381792
# elapsed time for k point: 0.013288021087646484
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 74.2801%)
#     iteration    1: trace = 0.2117470156936419 (1.05284% change)
#     iteration    2: trace = 0.2116582665555014 (0.0419216% change)
#     iteration    3: trace = 0.2116543821066921 (0.00183526% change)
#     iteration    4: trace = 0.2116543030491554 (3.73522e-05% change)
#     iteration    5: trace = 0.2116542961504078 (3.25944e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.241077, 0.391837
# elapsed time for k point: 0.013042688369750977
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 72.2826%)
#     iteration    1: trace = 0.221678075606871 (1.46045% change)
#     iteration    2: trace = 0.2215283673077369 (0.0675569% change)
#     iteration    3: trace = 0.221521723998813 (0.0029989% change)
#     iteration    4: trace = 0.2215215401623994 (8.2988e-05% change)
#     iteration    5: trace = 0.2215212963546022 (0.000110061% change)
#     switching back to exact line minimization
#     large trace change predicted (0.00500439%)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.221510860559777 (0.00471108% change)
#     large trace change predicted (0.164522%)
#     large theta (-4.63587)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.2214558653986456 (0.0248304% change)
#     linmin: converged after 5 iterations.
#     iteration    8: trace = 0.2214309237685239 (0.0112632% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 0.2214281884226458 (0.00123531% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.2214280584627549 (5.86917e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.2214280496914432 (3.96125e-06% change)
# Finished solving for bands 1 to 2 after 11 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.242759, 0.403108
# elapsed time for k point: 0.02837848663330078
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.2361273141186821 (7.86693% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.8719%)
#     iteration    2: trace = 0.2350325429013271 (0.464713% change)
#     iteration    3: trace = 0.2336364624802175 (0.595764% change)
#     switching back to exact line minimization
#     large trace change predicted (3.38834%)
#     linmin: converged after 7 iterations.
#     iteration    4: trace = 0.2318405711766991 (0.771635% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.230079518351666 (0.762492% change)
#     linmin: converged after 6 iterations.
#     iteration    6: trace = 0.2280087914858155 (0.904073% change)
#     linmin: converged after 8 iterations.
#     iteration    7: trace = 0.2237326355702539 (1.89319% change)
#     linmin: converged after 9 iterations.
#     iteration    8: trace = 0.2111307429388615 (5.79579% change)
#     linmin: converged after 6 iterations.
#     iteration    9: trace = 0.2080376963233106 (1.4758% change)
#     linmin: converged after 6 iterations.
#     iteration   10: trace = 0.2056919779346552 (1.13394% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 0.2055736408482889 (0.0575478% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 0.2055171250208218 (0.0274955% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 0.2055073462303346 (0.00475825% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.2055065924626932 (0.000366784% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.2055065665058319 (1.26307e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.2055065572661724 (4.49604e-06% change)
# Finished solving for bands 1 to 2 after 16 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.231351, 0.389851
# elapsed time for k point: 0.05138540267944336
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.1976740806832443 (5.16021% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 74.9093%)
#     iteration    2: trace = 0.1975639308085607 (0.0557385% change)
#     iteration    3: trace = 0.1975587402153778 (0.00262733% change)
#     iteration    4: trace = 0.1975585855520237 (7.82873e-05% change)
#     iteration    5: trace = 0.1975585824993402 (1.5452e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.193192, 0.400294
# elapsed time for k point: 0.015009164810180664
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.1996712422625031 (5.50816% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.2752%)
#     iteration    2: trace = 0.1994512331889444 (0.110246% change)
#     iteration    3: trace = 0.1994423818178826 (0.00443796% change)
#     iteration    4: trace = 0.1994421167204307 (0.000132919% change)
#     iteration    5: trace = 0.1994421116973623 (2.51856e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.136354, 0.425264
# elapsed time for k point: 0.022066116333007812
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2104675431592634 (6.19339% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 72.9749%)
#     iteration    2: trace = 0.2095292580610608 (0.446806% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.2094712965990503 (0.0276665% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 59.6663%)
#     iteration    4: trace = 0.2094677905574694 (0.00167377% change)
#     iteration    5: trace = 0.2094675959761624 (9.28932e-05% change)
#     iteration    6: trace = 0.2094675898533984 (2.92301e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0701479, 0.452269
# elapsed time for k point: 0.03148317337036133
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.0367%)
#     iteration    1: trace = 0.2203687680730597 (4.88844% change)
#     iteration    2: trace = 0.2173961511142815 (1.35809% change)
#     iteration    3: trace = 0.2169266091249615 (0.216218% change)
#     iteration    4: trace = 0.2169097502640034 (0.00777199% change)
#     iteration    5: trace = 0.216906464823599 (0.00151467% change)
#     iteration    6: trace = 0.2169062560343905 (9.62578e-05% change)
#     iteration    7: trace = 0.2169062395750448 (7.58823e-06% change)
# Finished solving for bands 2 to 2 after 7 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.465732
# elapsed time for k point: 0.02004075050354004
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.24275923045403475 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.36715955722068355 at Vector3<0.0, 0.5, 0.0> to 0.4657319396123106 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.24275923045403475) to band 2 (0.36715955722068355), 40.792423280128226%
# total elapsed time for run: 0.41488027572631836
# done
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 7.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.347214, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.01982569694519043
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2
# Solving for bands 2 to 2...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 0.5276280489666746 (198.958% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 0.2119011720850342 (85.3859% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1838220554141289 (14.1913% change)
#     linmin: converged after 8 iterations.
#     iteration    4: trace = 0.148123722304207 (21.5085% change)
#     linmin: converged after 5 iterations.
#     switching to approximate line minimization (decrease time by 82.0715%)
#     iteration    5: trace = 0.1420776201096957 (4.16683% change)
#     iteration    6: trace = 0.1415746128435659 (0.354665% change)
#     iteration    7: trace = 0.1414265240344026 (0.104656% change)
#     iteration    8: trace = 0.141386888592997 (0.0280294% change)
#     iteration    9: trace = 0.1413817945587453 (0.00360297% change)
#     iteration   10: trace = 0.1413788014701936 (0.00211705% change)
#     iteration   11: trace = 0.1413785149105202 (0.000202689% change)
#     iteration   12: trace = 0.141378253230066 (0.000185092% change)
#     iteration   13: trace = 0.1413782232778762 (2.11859e-05% change)
#     iteration   14: trace = 0.141378161312084 (4.38298e-05% change)
#     iteration   15: trace = 0.1413781183870005 (3.03619e-05% change)
#     iteration   16: trace = 0.1413775857696616 (0.000376733% change)
#     iteration   17: trace = 0.141376381432214 (0.000851862% change)
#     iteration   18: trace = 0.1413697115104122 (0.00471796% change)
#     iteration   19: trace = 0.1413540977799411 (0.0110452% change)
#     iteration   20: trace = 0.1413466352599626 (0.00527945% change)
#     iteration   21: trace = 0.1413378949459169 (0.00618379% change)
#     iteration   22: trace = 0.1413363285441037 (0.00110827% change)
#     iteration   23: trace = 0.1413352655288183 (0.00075212% change)
#     iteration   24: trace = 0.1413351712414416 (6.67119e-05% change)
#     iteration   25: trace = 0.1413351264465134 (3.16941e-05% change)
#     iteration   26: trace = 0.1413351193157739 (5.04527e-06% change)
# Finished solving for bands 2 to 2 after 26 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.375946
# elapsed time for k point: 0.058949947357177734
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 0.1394764778042855 (9.02839% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.1379125039382698 (1.12764% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 63.5814%)
#     iteration    3: trace = 0.1376846015994065 (0.165388% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.1370518416137279 (0.460631% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 71.0092%)
#     iteration    5: trace = 0.1366666120701861 (0.281479% change)
#     switching back to exact line minimization
#     iteration    6: trace = 0.1366261255222476 (0.0296287% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 63.42%)
#     iteration    7: trace = 0.1366219499765486 (0.00305623% change)
#     iteration    8: trace = 0.136621648495509 (0.000220668% change)
#     iteration    9: trace = 0.1366213198128844 (0.000240579% change)
#     iteration   10: trace = 0.1366208723064801 (0.000327553% change)
#     iteration   11: trace = 0.1366207262647222 (0.000106896% change)
#     iteration   12: trace = 0.1366207107733565 (1.1339e-05% change)
#     iteration   13: trace = 0.1366207093003199 (1.07819e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0477425, 0.366526
# elapsed time for k point: 0.027936220169067383
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.1279831117931228 (8.85079% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 65.2821%)
#     iteration    2: trace = 0.127266167807222 (0.56176% change)
#     iteration    3: trace = 0.1272408058129705 (0.0199303% change)
#     iteration    4: trace = 0.1272396766268223 (0.000887444% change)
#     iteration    5: trace = 0.1272396028021431 (5.80202e-05% change)
#     iteration    6: trace = 0.127239564476182 (3.01211e-05% change)
#     iteration    7: trace = 0.1272395492882057 (1.19365e-05% change)
#     iteration    8: trace = 0.1272395481311894 (9.09321e-07% change)
# Finished solving for bands 1 to 2 after 8 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.0944768, 0.343968
# elapsed time for k point: 0.0328516960144043
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.1191233557908009 (8.13559% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.1188149200826784 (0.259257% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 69.6696%)
#     iteration    3: trace = 0.1188040041896662 (0.00918773% change)
#     iteration    4: trace = 0.1188034799611923 (0.000441256% change)
#     iteration    5: trace = 0.1188034674955364 (1.04927e-05% change)
#     iteration    6: trace = 0.1188034665349696 (8.08534e-07% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.138837, 0.31548
# elapsed time for k point: 0.021615266799926758
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.1135703071277273 (8.14818% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 60.7951%)
#     iteration    2: trace = 0.1133860837865745 (0.162343% change)
#     iteration    3: trace = 0.1133803042772395 (0.00509732% change)
#     iteration    4: trace = 0.1133800981350733 (0.000181815% change)
#     iteration    5: trace = 0.1133800937949902 (3.82791e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.177681, 0.286024
# elapsed time for k point: 0.015024662017822266
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.1116812686265736 (8.24233% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 72.4691%)
#     iteration    2: trace = 0.1115384779490058 (0.127937% change)
#     iteration    3: trace = 0.1115345546534855 (0.0035175% change)
#     iteration    4: trace = 0.1115344004171967 (0.000138286% change)
#     iteration    5: trace = 0.1115343980472989 (2.12481e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.197617, 0.269225
# elapsed time for k point: 0.014787435531616211
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.1868%)
#     iteration    1: trace = 0.1127300330042682 (0.335328% change)
#     iteration    2: trace = 0.11271469219745 (0.0136094% change)
#     iteration    3: trace = 0.1127143618088057 (0.00029312% change)
#     iteration    4: trace = 0.1127143553550984 (5.72572e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.198586, 0.270699
# elapsed time for k point: 0.01694798469543457
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 66.1522%)
#     iteration    1: trace = 0.1161953131832837 (0.457051% change)
#     iteration    2: trace = 0.116172549145241 (0.0195931% change)
#     iteration    3: trace = 0.1161720714833167 (0.000411167% change)
#     iteration    4: trace = 0.116172057922868 (1.16727e-05% change)
#     iteration    5: trace = 0.1161720576205227 (2.60256e-07% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.201331, 0.275023
# elapsed time for k point: 0.019644737243652344
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 66.8333%)
#     iteration    1: trace = 0.1216758346014823 (0.714079% change)
#     iteration    2: trace = 0.121631184662283 (0.0367025% change)
#     iteration    3: trace = 0.1216302493412962 (0.000768984% change)
#     iteration    4: trace = 0.1216302172523166 (2.63824e-05% change)
#     iteration    5: trace = 0.121630216555193 (5.7315e-07% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.205314, 0.281916
# elapsed time for k point: 0.015620231628417969
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.5651%)
#     iteration    1: trace = 0.1286084433010798 (1.11391% change)
#     iteration    2: trace = 0.1285059786609447 (0.0797035% change)
#     iteration    3: trace = 0.1285037253082301 (0.00175352% change)
#     iteration    4: trace = 0.1285036400478162 (6.63486e-05% change)
#     iteration    5: trace = 0.1285036380045926 (1.59001e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.209416, 0.290945
# elapsed time for k point: 0.0272066593170166
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 76.8498%)
#     iteration    1: trace = 0.1359176771286306 (1.69644% change)
#     iteration    2: trace = 0.1356817498632591 (0.173732% change)
#     iteration    3: trace = 0.1356761698140158 (0.00411269% change)
#     iteration    4: trace = 0.1356759316340368 (0.00017555% change)
#     iteration    5: trace = 0.1356759245658913 (5.20958e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.211492, 0.301575
# elapsed time for k point: 0.014006614685058594
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.1286117773669243 (8.57765% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 61.016%)
#     iteration    2: trace = 0.1264134118716094 (1.72404% change)
#     iteration    3: trace = 0.1253619781639351 (0.835216% change)
#     iteration    4: trace = 0.1252789397161146 (0.0662609% change)
#     iteration    5: trace = 0.125274303692744 (0.00370063% change)
#     iteration    6: trace = 0.1252737641382059 (0.000430699% change)
#     iteration    7: trace = 0.125273540022832 (0.000178901% change)
#     iteration    8: trace = 0.1252735232541741 (1.33856e-05% change)
#     iteration    9: trace = 0.1252735227616628 (3.93149e-07% change)
# Finished solving for bands 1 to 2 after 9 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.197206, 0.29391
# elapsed time for k point: 0.019458770751953125
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 2...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.1221383014958789 (6.44087% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 75.8809%)
#     iteration    2: trace = 0.1220666958218325 (0.0586439% change)
#     iteration    3: trace = 0.122064724902267 (0.00161464% change)
#     iteration    4: trace = 0.1220646489049205 (6.22599e-05% change)
#     iteration    5: trace = 0.1220646472983046 (1.3162e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.158018, 0.3116
# elapsed time for k point: 0.014535903930664062
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.1264345640393397 (7.0455% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 76.3447%)
#     iteration    2: trace = 0.1262424078885289 (0.152096% change)
#     iteration    3: trace = 0.12623688982905 (0.0043711% change)
#     iteration    4: trace = 0.1262367030055141 (0.000147995% change)
#     iteration    5: trace = 0.1262366983440416 (3.69264e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.108543, 0.338312
# elapsed time for k point: 0.018226146697998047
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.1362019999712507 (8.09702% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 94.8451%)
#     iteration    2: trace = 0.1355038698191315 (0.513887% change)
#     iteration    3: trace = 0.1354543221055833 (0.0365722% change)
#     iteration    4: trace = 0.1354532825924654 (0.00076743% change)
#     iteration    5: trace = 0.1354532090006901 (5.433e-05% change)
#     iteration    6: trace = 0.1354532055307006 (2.56176e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0550658, 0.363897
# elapsed time for k point: 0.02495598793029785
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 97.4275%)
#     iteration    1: trace = 0.1466301528422088 (4.29365% change)
#     iteration    2: trace = 0.1422493639211493 (3.03295% change)
#     iteration    3: trace = 0.1413698058056105 (0.620239% change)
#     iteration    4: trace = 0.1413429581929305 (0.0189929% change)
#     iteration    5: trace = 0.1413357682470836 (0.00508701% change)
#     iteration    6: trace = 0.1413353288958088 (0.000310857% change)
#     iteration    7: trace = 0.1413351225663411 (0.000145986% change)
#     iteration    8: trace = 0.1413351120145999 (7.46576e-06% change)
# Finished solving for bands 2 to 2 after 8 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.375946
# elapsed time for k point: 0.03833460807800293
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2114915377030098 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.26922455687638036 at Vector3<0.0, 0.5, 0.0> to 0.3759456334575173 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2114915377030098) to band 2 (0.26922455687638036), 24.01959069994731%
# total elapsed time for run: 0.40412044525146484
# done
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 7.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.194427, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.02700328826904297
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2
# Solving for bands 2 to 2...
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 2.172653024504913 (196.021% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 0.38681358748859 (139.548% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.3416678148123099 (12.3945% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 95.5354%)
#     iteration    4: trace = 0.3372105173627339 (1.31314% change)
#     iteration    5: trace = 0.3338836661078707 (0.991471% change)
#     iteration    6: trace = 0.3310076870303307 (0.865097% change)
#     iteration    7: trace = 0.330088915545512 (0.277954% change)
#     iteration    8: trace = 0.329565361378578 (0.158736% change)
#     iteration    9: trace = 0.3294264788917877 (0.04215% change)
#     iteration   10: trace = 0.3293260005945904 (0.0305056% change)
#     iteration   11: trace = 0.3292154696932266 (0.0335684% change)
#     iteration   12: trace = 0.3291721592858505 (0.0131565% change)
#     iteration   13: trace = 0.3291632451522953 (0.00270808% change)
#     iteration   14: trace = 0.3291594671436423 (0.00114777% change)
#     iteration   15: trace = 0.3291541957122117 (0.0016015% change)
#     iteration   16: trace = 0.3291493977023452 (0.00145769% change)
#     iteration   17: trace = 0.3291477247042981 (0.000508281% change)
#     iteration   18: trace = 0.3291471326097484 (0.000179887% change)
#     iteration   19: trace = 0.3291460953926021 (0.000315123% change)
#     iteration   20: trace = 0.3291436404192755 (0.000745864% change)
#     iteration   21: trace = 0.3291411965332279 (0.000742501% change)
#     iteration   22: trace = 0.3291397977579203 (0.000424978% change)
#     iteration   23: trace = 0.3291370856456299 (0.000824004% change)
#     iteration   24: trace = 0.3291283296319628 (0.00266033% change)
#     iteration   25: trace = 0.3291116416482188 (0.00507049% change)
#     iteration   26: trace = 0.3291034775716579 (0.00248067% change)
#     iteration   27: trace = 0.3290987361621018 (0.00144072% change)
#     iteration   28: trace = 0.3290912486633286 (0.00227518% change)
#     iteration   29: trace = 0.3290824148983701 (0.00268433% change)
#     iteration   30: trace = 0.3290794521113749 (0.000900322% change)
#     iteration   31: trace = 0.3290788075552082 (0.000195867% change)
#     iteration   32: trace = 0.3290784602585138 (0.000105536% change)
#     iteration   33: trace = 0.3290779537683027 (0.000153912% change)
#     iteration   34: trace = 0.3290777180023224 (7.16444e-05% change)
#     iteration   35: trace = 0.3290776634202421 (1.65864e-05% change)
#     iteration   36: trace = 0.3290776472288059 (4.92025e-06% change)
# Finished solving for bands 2 to 2 after 36 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.573653
# elapsed time for k point: 0.07175564765930176
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
#     linmin: converged after 8 iterations.
#     switching to approximate line minimization (decrease time by 66.4997%)
#     iteration    1: trace = 0.3309444406850064 (4.01957% change)
#     iteration    2: trace = 0.3298641435781935 (0.326962% change)
#     iteration    3: trace = 0.3244950605380113 (1.64102% change)
#     iteration    4: trace = 0.3200317488165993 (1.38499% change)
#     iteration    5: trace = 0.3181472923495112 (0.590573% change)
#     iteration    6: trace = 0.3156752627316602 (0.780038% change)
#     iteration    7: trace = 0.3130444828421352 (0.836869% change)
#     iteration    8: trace = 0.3104552164573217 (0.830559% change)
#     iteration    9: trace = 0.3084027897011443 (0.663295% change)
#     iteration   10: trace = 0.3069630217399457 (0.467939% change)
#     iteration   11: trace = 0.3062507552587932 (0.232306% change)
#     iteration   12: trace = 0.3061202369610322 (0.0426272% change)
#     iteration   13: trace = 0.3060997536922768 (0.00669147% change)
#     iteration   14: trace = 0.3060908518440021 (0.00290819% change)
#     iteration   15: trace = 0.3060857945207642 (0.00165224% change)
#     iteration   16: trace = 0.3060813387795022 (0.00145573% change)
#     iteration   17: trace = 0.306079594053175 (0.000570022% change)
#     iteration   18: trace = 0.3060793890982298 (6.69613e-05% change)
#     iteration   19: trace = 0.3060793064189577 (2.70124e-05% change)
#     iteration   20: trace = 0.3060792329471007 (2.40042e-05% change)
#     iteration   21: trace = 0.3060791921039821 (1.3344e-05% change)
#     iteration   22: trace = 0.3060791637109301 (9.27637e-06% change)
# Finished solving for bands 1 to 2 after 22 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0723653, 0.548491
# elapsed time for k point: 0.05244636535644531
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.2880740743611357 (3.25326% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 61.6569%)
#     iteration    2: trace = 0.2877265764481527 (0.120701% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.287709890683601 (0.00579934% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 73.8419%)
#     iteration    4: trace = 0.2877093355853514 (0.000192937% change)
#     iteration    5: trace = 0.2877092865031122 (1.70597e-05% change)
#     iteration    6: trace = 0.2877092584539553 (9.74913e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.141304, 0.517438
# elapsed time for k point: 0.032407522201538086
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 70.2479%)
#     iteration    1: trace = 0.2800414241488122 (3.76509% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.2796199352280735 (0.150623% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 65.7912%)
#     iteration    3: trace = 0.2795970756633197 (0.00817556% change)
#     iteration    4: trace = 0.2795963398935442 (0.000263154% change)
#     iteration    5: trace = 0.2795963173642044 (8.05781e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.202349, 0.488519
# elapsed time for k point: 0.01919245719909668
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.2780871622392607 (4.56459% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 59.0821%)
#     iteration    2: trace = 0.2776059288072302 (0.173201% change)
#     iteration    3: trace = 0.2775863945895399 (0.00703692% change)
#     iteration    4: trace = 0.2775856686671364 (0.000261513% change)
#     iteration    5: trace = 0.2775856525848627 (5.79363e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.248137, 0.464773
# elapsed time for k point: 0.01567816734313965
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.2780084122737583 (5.21352% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 72.3795%)
#     iteration    2: trace = 0.2775236665748678 (0.174516% change)
#     iteration    3: trace = 0.2775065097510162 (0.0061823% change)
#     iteration    4: trace = 0.2775057189756694 (0.000284958% change)
#     iteration    5: trace = 0.2775057070071837 (4.31288e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.266297, 0.454523
# elapsed time for k point: 0.02152419090270996
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 88.0901%)
#     iteration    1: trace = 0.2801053924889785 (0.347825% change)
#     iteration    2: trace = 0.2800767894172544 (0.0102121% change)
#     iteration    3: trace = 0.2800755755609996 (0.000433402% change)
#     iteration    4: trace = 0.2800755543275952 (7.58131e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.267275, 0.456771
# elapsed time for k point: 0.014524698257446289
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 95.1101%)
#     iteration    1: trace = 0.2875880435006899 (0.42942% change)
#     iteration    2: trace = 0.2875461692359655 (0.0145616% change)
#     iteration    3: trace = 0.287544491140917 (0.000583593% change)
#     iteration    4: trace = 0.2875444496884508 (1.4416e-05% change)
#     iteration    5: trace = 0.2875444481549322 (5.33315e-07% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.269988, 0.463304
# elapsed time for k point: 0.023180246353149414
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 72.4983%)
#     iteration    1: trace = 0.299236724866479 (0.601899% change)
#     iteration    2: trace = 0.2991690402443274 (0.0226216% change)
#     iteration    3: trace = 0.2991663819256077 (0.000888571% change)
#     iteration    4: trace = 0.2991662985745033 (2.78611e-05% change)
#     iteration    5: trace = 0.2991662927484057 (1.94744e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.273756, 0.473523
# elapsed time for k point: 0.024619102478027344
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 63.837%)
#     iteration    1: trace = 0.3137391376334649 (0.857109% change)
#     iteration    2: trace = 0.3136309490542617 (0.0344896% change)
#     iteration    3: trace = 0.3136265266451811 (0.00141008% change)
#     iteration    4: trace = 0.3136263422368155 (5.87987e-05% change)
#     iteration    5: trace = 0.3136262760369574 (2.11079e-05% change)
#     iteration    6: trace = 0.3136262261338199 (1.59117e-05% change)
#     iteration    7: trace = 0.3136262240420712 (6.66956e-07% change)
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.277382, 0.486503
# elapsed time for k point: 0.015714406967163086
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 63.3597%)
#     iteration    1: trace = 0.3291608601970262 (1.18367% change)
#     iteration    2: trace = 0.3289953710253657 (0.0502887% change)
#     iteration    3: trace = 0.3289877701981476 (0.00231034% change)
#     iteration    4: trace = 0.3289868543115466 (0.000278396% change)
#     iteration    5: trace = 0.3289783751046007 (0.0025774% change)
#     switching back to exact line minimization
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    6: trace = 0.3287395130528968 (0.0726336% change)
#     linmin: converged after 5 iterations.
#     iteration    7: trace = 0.3286384752901774 (0.0307396% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.3286293052036058 (0.00279037% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.3286291048801722 (6.09573e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.3286290923975338 (3.7984e-06% change)
# Finished solving for bands 1 to 2 after 10 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.279087, 0.500739
# elapsed time for k point: 0.03246784210205078
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.3532951723513005 (6.37954% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 68.8369%)
#     iteration    2: trace = 0.3522958648809289 (0.283254% change)
#     iteration    3: trace = 0.3521309977751608 (0.0468089% change)
#     switching back to exact line minimization
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    4: trace = 0.3315787867733365 (6.01197% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.3310141965481935 (0.170418% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.3303008031097538 (0.21575% change)
#     linmin: converged after 5 iterations.
#     iteration    7: trace = 0.3292991001414727 (0.30373% change)
#     linmin: converged after 6 iterations.
#     iteration    8: trace = 0.3275099173550099 (0.544811% change)
#     linmin: converged after 10 iterations.
#     iteration    9: trace = 0.3191141164306555 (2.59681% change)
#     linmin: converged after 12 iterations.
#     iteration   10: trace = 0.3150530546241571 (1.28075% change)
#     linmin: converged after 10 iterations.
# ...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.024065494537353516
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2
# Solving for bands 2 to 2...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 1.282327213027733 (197.717% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 0.3727183312245143 (109.919% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 85.327%)
#     iteration    3: trace = 0.3562226014949299 (4.52594% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.3552054926493984 (0.285934% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 73.6445%)
#     iteration    5: trace = 0.354790161464302 (0.116995% change)
#     iteration    6: trace = 0.3547490992170868 (0.0115743% change)
#     iteration    7: trace = 0.354746667613946 (0.000685445% change)
#     iteration    8: trace = 0.3547465704588875 (2.73872e-05% change)
#     iteration    9: trace = 0.3547465472864217 (6.53212e-06% change)
# Finished solving for bands 2 to 2 after 9 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.595606
# elapsed time for k point: 0.04524850845336914
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.2576%)
#     iteration    1: trace = 0.357075228822811 (4.27716% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.3504363492121669 (1.87668% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.3499791567544841 (0.130549% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 77.1547%)
#     iteration    4: trace = 0.3499382769456573 (0.0116813% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.3499344423590683 (0.0010958% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 79.7824%)
#     iteration    6: trace = 0.3499339954432649 (0.000127714% change)
#     iteration    7: trace = 0.3499339545734999 (1.16793e-05% change)
#     iteration    8: trace = 0.349933946867551 (2.20212e-06% change)
# Finished solving for bands 1 to 2 after 8 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0810781, 0.58597
# elapsed time for k point: 0.055858612060546875
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 83.951%)
#     iteration    1: trace = 0.3476045831780563 (3.65241% change)
#     iteration    2: trace = 0.3449095151297322 (0.778343% change)
#     iteration    3: trace = 0.3447387210655011 (0.0495308% change)
#     iteration    4: trace = 0.3447327535709358 (0.00173103% change)
#     iteration    5: trace = 0.3447324598658248 (8.51979e-05% change)
#     iteration    6: trace = 0.3447324154122497 (1.28951e-05% change)
#     iteration    7: trace = 0.3447324101201869 (1.53512e-06% change)
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.158569, 0.565321
# elapsed time for k point: 0.06797337532043457
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 62.2147%)
#     iteration    1: trace = 0.3471711427996441 (3.69241% change)
#     iteration    2: trace = 0.3458490828250698 (0.381536% change)
#     iteration    3: trace = 0.3457733274104349 (0.0219066% change)
#     iteration    4: trace = 0.345770771374782 (0.000739226% change)
#     iteration    5: trace = 0.3457707067922461 (1.86778e-05% change)
#     iteration    6: trace = 0.3457706993929722 (2.13994e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.227497, 0.542232
# elapsed time for k point: 0.03413987159729004
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 75.4436%)
#     iteration    1: trace = 0.3513037171958263 (4.42485% change)
#     iteration    2: trace = 0.3503151928996014 (0.281784% change)
#     iteration    3: trace = 0.3502831364045222 (0.00915118% change)
#     iteration    4: trace = 0.3502817047878608 (0.000408704% change)
#     iteration    5: trace = 0.3502816795009415 (7.21902e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.279263, 0.521818
# elapsed time for k point: 0.04478049278259277
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.3536154352548043 (5.21006% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 74.5413%)
#     iteration    2: trace = 0.3527118571618239 (0.255853% change)
#     iteration    3: trace = 0.3526971961060275 (0.00415675% change)
#     iteration    4: trace = 0.3526963777952201 (0.000232015% change)
#     iteration    5: trace = 0.3526963649167986 (3.65142e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.29971, 0.512709
# elapsed time for k point: 0.03554797172546387
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 79.3556%)
#     iteration    1: trace = 0.3563548342727424 (0.27402% change)
#     iteration    2: trace = 0.3563320255879394 (0.00640076% change)
#     iteration    3: trace = 0.3563311215654697 (0.000253703% change)
#     iteration    4: trace = 0.3563311031487059 (5.16844e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.300784, 0.515616
# elapsed time for k point: 0.030877113342285156
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 61.5601%)
#     iteration    1: trace = 0.3670198451337732 (0.336258% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.3669821986053142 (0.0102579% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 73.9163%)
#     iteration    3: trace = 0.3669806957515346 (0.000409518% change)
#     iteration    4: trace = 0.3669806641341758 (8.61554e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.303762, 0.524127
# elapsed time for k point: 0.04017472267150879
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 74.3966%)
#     iteration    1: trace = 0.3839096962206751 (0.471364% change)
#     iteration    2: trace = 0.3838423112416649 (0.0175538% change)
#     iteration    3: trace = 0.383839460381047 (0.000742719% change)
#     iteration    4: trace = 0.3838393949476404 (1.70471e-05% change)
#     iteration    5: trace = 0.3838393881000531 (1.78397e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.307893, 0.537626
# elapsed time for k point: 0.049367666244506836
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.2198%)
#     iteration    1: trace = 0.405551985060337 (0.679099% change)
#     iteration    2: trace = 0.4054355172100402 (0.0287225% change)
#     iteration    3: trace = 0.4054301629182252 (0.00132064% change)
#     iteration    4: trace = 0.4054300041929568 (3.91498e-05% change)
#     iteration    5: trace = 0.4054299395142656 (1.59531e-05% change)
#     iteration    6: trace = 0.4054299095061101 (7.40156e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.311867, 0.55513
# elapsed time for k point: 0.04775094985961914
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 76.25%)
#     iteration    1: trace = 0.4296464142936191 (0.959195% change)
#     iteration    2: trace = 0.4294546655365195 (0.0446394% change)
#     iteration    3: trace = 0.4294446504599332 (0.00233207% change)
#     iteration    4: trace = 0.4294436771307462 (0.000226649% change)
#     iteration    5: trace = 0.4294332760865649 (0.00242201% change)
#     switching back to exact line minimization
#     large trace change predicted (2.00773%)
#     large theta (-24.2701)
#     linmin: converged after 7 iterations.
#     iteration    6: trace = 0.4292266505383527 (0.0481274% change)
#     linmin: converged after 9 iterations.
#     iteration    7: trace = 0.4290419507513125 (0.0430401% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.4290285035549944 (0.00313429% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4290278628126263 (0.000149347% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.4290278204551438 (9.8729e-06% change)
# Finished solving for bands 1 to 2 after 10 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.313735, 0.574977
# elapsed time for k point: 0.09171748161315918
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.4716629980524208 (5.47746% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.0115%)
#     iteration    2: trace = 0.4689185004454886 (0.583575% change)
#     switching back to exact line minimization
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    3: trace = 0.4244552216653229 (9.95402% change)
#     linmin: converged after 7 iterations.
#     iteration    4: trace = 0.4071348359036125 (4.16561% change)
#     linmin: converged after 7 iterations.
#     iteration    5: trace = 0.38811690383641 (4.78287% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.3870979710678852 (0.262878% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 0.3868223920819531 (0.0712164% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.386741647944625 (0.0208759% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.3867347665981912 (0.00177933% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.3867346274647867 (3.59764e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.3867346192318266 (2.12884e-06% change)
# Finished solving for bands 1 to 2 after 11 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.300888, 0.544244
# elapsed time for k point: 0.06292128562927246
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 78.4395%)
#     iteration    1: trace = 0.3588326582979336 (3.38131% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.3581373466335517 (0.193958% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 81.1347%)
#     iteration    3: trace = 0.3581021015921489 (0.00984169% change)
#     iteration    4: trace = 0.3581010799163941 (0.000285303% change)
#     iteration    5: trace = 0.3581010403048863 (1.10615e-05% change)
#     iteration    6: trace = 0.3581010396351456 (1.87026e-07% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.254641, 0.541534
# elapsed time for k point: 0.03245830535888672
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 67.8571%)
#     iteration    1: trace = 0.3472637035065741 (3.54903% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.3461664865668469 (0.316461% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 66.7147%)
#     iteration    3: trace = 0.3460586601182022 (0.0311536% change)
#     iteration    4: trace = 0.3460557990861016 (0.000826751% change)
#     iteration    5: trace = 0.3460556501551606 (4.30367e-05% change)
#     iteration    6: trace = 0.3460556449685027 (1.49879e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.181117, 0.559689
# elapsed time for k point: 0.03332185745239258
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 2...
#     linmin: converged after 7 iterations.
#     switching to approximate line minimization (decrease time by 62.1581%)
#     iteration    1: trace = 0.3519925265807727 (3.72363% change)
#     iteration    2: trace = 0.3494396061755118 (0.727917% change)
#     iteration    3: trace = 0.3489435390207942 (0.142062% change)
#     iteration    4: trace = 0.3489186226722207 (0.00714077% change)
#     iteration    5: trace = 0.3489173106230793 (0.000376034% change)
#     iteration    6: trace = 0.3489171332263175 (5.08421e-05% change)
#     iteration    7: trace = 0.348917111283003 (6.28898e-06% change)
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0934014, 0.583261
# elapsed time for k point: 0.04813194274902344
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 78.017%)
#     iteration    1: trace = 0.3626066752645919 (4.40475% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.3559105875283782 (1.86386% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.354942488176105 (0.272377% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.9899%)
#     iteration    4: trace = 0.3547543056197123 (0.0530318% change)
#     iteration    5: trace = 0.3547473445420504 (0.00196224% change)
#     iteration    6: trace = 0.3547467028345879 (0.000180892% change)
#     iteration    7: trace = 0.3547465662297394 (3.85077e-05% change)
#     iteration    8: trace = 0.3547465427063073 (6.63105e-06% change)
# Finished solving for bands 2 to 2 after 8 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.595606
# elapsed time for k point: 0.03339362144470215
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3137350050204336 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.5127086406144166 at Vector3<0.0, 0.5, 0.0> to 0.5956060336215724 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.3137350050204336) to band 2 (0.5127086406144166), 48.15177335924391%
# total elapsed time for run: 0.786691427230835
# done
# radius at maximum: 0.15835921350012622
# gap size at maximum: 48.151773359243904

# %%
ms.mesh_size = 3  # Reset to default value of 3

# %%
ms.geometry = [mp.Cylinder(radius=0.3, material=mp.Medium(epsilon_diag=mp.Vector3(1, 1, 12)))]

# %%
ms.default_material = mp.Medium(epsilon_diag=mp.Vector3(12, 12, 1))

# %%
ms.num_bands = 8
ms.run()  # just use run, instead of run_te or run_tm, to find the complete gap
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.3, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.04405856132507324
# solve_kpoint (0,0,0):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8
# Solving for bands 3 to 8...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 12.93577339330503 (192.976% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 3.853575821085383 (108.19% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.193438268457903 (54.9077% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.550829902652088 (34.3249% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.359184319771552 (13.1715% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.251942866245228 (8.21419% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.205667116092169 (3.76591% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 1.177785942963212 (2.33956% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 1.154490790467843 (1.99763% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 1.13683085891941 (1.54146% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.121782812948786 (1.3325% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace =
to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.022750177953547 (1.54325% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.013084853885142 (0.949519% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.008980961891683 (0.405911% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.005147987973319 (0.380609% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.002882906693539 (0.225602% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.001352478157919 (0.152719% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.00070268109903 (0.064913% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.000497341464406 (0.0205217% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.000304011997076 (0.0193252% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.000207589800639 (0.00963975% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.000130459846442 (0.00771169% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.000080272448751 (0.00501821% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 1.000061236394542 (0.00190347% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 1.000051858578933 (0.000937729% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 1.000045830403216 (0.000602788% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.00004212023895 (0.000371% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.000040700015168 (0.000142016% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.000039832298043 (8.67682e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.000039604209905 (2.28079e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.000039520005295 (8.42013e-06% change)
# Finished solving for bands 3 to 8 after 20 iterations.
# freqs:, 16, 0, 0, 0, 0, 0, 0, 0.366827, 0.411783, 0.411791, 0.418096, 0.418405, 0.420087
# elapsed time for k point: 0.625403642654419
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.20715288761356718 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.22413162481424814 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 3 range: 0.2745028221119146 at Vector3<0.0, 0.5, 0.0> to 0.36682698517147605 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.291228666878296 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.4117834115009872 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.32575958121785303 at Vector3<-0.2, 0.39999999999999997, 0.0> to 0.4117908890281248 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.3459056603043383 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.41809584548189793 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.40878191575569767 at Vector3<0.0, 0.5, 0.0> to 0.46180035109072376 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 8 range: 0.4200872428044834 at Vector3<0.0, 0.0, 0.0> to 0.5068478128012375 at Vector3<0.0, 0.5, 0.0>
# Gap from band 2 (0.22413162481424814) to band 3 (0.2745028221119146), 20.20365725159192%
# total elapsed time for run: 16.75094699859619
# done

# %%
ms.geometry_lattice = mp.Lattice(size=mp.Vector3(5, 5))

# %%
ms.geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]
ms.geometry = mp.geometric_objects_lattice_duplicates(ms.geometry_lattice, ms.geometry)

# %%
ms.geometry.append(mp.Cylinder(0.2, material=mp.air))

# %%
ms.resolution = 16

# %%
ms.k_points = [mp.Vector3(0.5, 0.5)]

# %%
ms.num_bands = 50

# %%
mpb.output_efield_z(ms, 25)

# %%
ms.get_dfield(25)  # compute the D field for band 25
ms.compute_field_energy()  # compute the energy density from D
c = mp.Cylinder(1.0, material=mp.air)
print("energy in cylinder: {}".format(ms.compute_energy_in_objects([c])))

# %%
ms.num_bands = 1  # only need to compute a single band, now!
ms.target_freq = (0.2812 + 0.4174) / 2
ms.tolerance = 1e-8

# %%
from scipy.optimize import ridder

old_geometry = ms.geometry  # save the 5x5 grid with a missing rod

def rootfun(eps):
    # add the cylinder of epsilon = eps to the old geometry:
    ms.geometry = old_geometry + [mp.Cylinder(0.2, material=mp.Medium(epsilon=eps))]
    ms.run_tm()  # solve for the mode (using the targeted solver)
    print("epsilon = {} gives freq. =  {}".format(eps, ms.get_freqs()[0]))
    return ms.get_freqs()[0] - 0.314159  # return 1st band freq. - 0.314159

# %%
rooteps = ridder(rootfun, 1, 12)
print("root (value of epsilon) is at: {}".format(rooteps))
