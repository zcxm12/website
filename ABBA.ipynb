# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
fmin = 0.424 #300THz
fmax = 0.450 #600THz
nf = 1000 
fcen = (fmin + fmax)/2
df = fmax - fmin
#dfp = 1/2
fre = np.linspace(fmin,fmax,nf)
omega = 2 * np.pi * fre

# %%
dpml = 1

dA = 0.2
dB = 0.3
epsilonA = 12
epsilonB = 3

NAB = 10

sz = 2*dpml+16

resolution = 100 # pixels/μm

cell_size = mp.Vector3(z=sz)

pml_layers = [mp.PML(dpml)]

source_z=-sz/2+dpml
flux_reg_z=sz/2-dpml
flux_z = 0.5*sz-dpml
pt = mp.Vector3(z=flux_z-0.5)

# %%
def BlockAB(N, center):
    geometry = []
    for i in range(N):
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA/2),
                     material=mp.Medium(epsilon=epsilonA)))
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA + dB/2),
                     material=mp.Medium(epsilon=epsilonB)))
    geometry = geometry.tolist()
    return geometry

# %%
def BlockBA(N, center):
    geometry = []
    for i in range(N):
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB/2),
                     material=mp.Medium(epsilon=epsilonB)))
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                     center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB + dA/2),
                     material=mp.Medium(epsilon=epsilonA)))
    geometry = geometry.tolist()
    return geometry

# %%
sources = [mp.Source(mp.GaussianSource(fcen,fwidth=df),
                     component=mp.Ex,
                     center=mp.Vector3(z=source_z),
                     size=mp.Vector3())]
geometry = sum([BlockBA(5,5*(dA+dB)/2),BlockAB(5,-5*(dA+dB)/2)],[])

# %%
sim_vac = mp.Simulation(cell_size=cell_size,
                    resolution=resolution,
                    boundary_layers=pml_layers,
                    dimensions=1,
                    sources=sources)
refl_fr = mp.FluxRegion(center=mp.Vector3(z=-8))
refl = sim_vac.add_flux(fcen, df,nf, refl_fr)
tran_fr = mp.FluxRegion(center=mp.Vector3(z=8))
tran = sim_vac.add_flux(fcen, df, nf, tran_fr)
sim_vac.run(until_after_sources=mp.stop_when_fields_decayed(50,mp.Ex,
                                                            mp.Vector3(z=0),1e-3))
empty_flux = mp.get_fluxes(tran)
empty_data = sim_vac.get_flux_data(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
# time for set_epsilon = 0.000405073 s
# -----------
# field decay(t = 50.005): 5.055837786485036e-08 / 5.055837786485036e-08 = 1.0
# field decay(t = 100.01): 0.0002647093489360384 / 0.0002647093489360384 = 1.0
# field decay(t = 150.01500000000001): 0.045102100861563736 / 0.045102100861563736 = 1.0
# field decay(t = 200.02): 0.2498181430059178 / 0.2498181430059178 = 1.0
# field decay(t = 250.025): 0.2500429210709593 / 0.2500429210709593 = 1.0
# field decay(t = 300.03000000000003): 0.045104820049037986 / 0.2500429210709593 = 0.18038831035827546
# field decay(t = 350.035): 0.0002647415996300667 / 0.2500429210709593 = 0.0010587846218407281
# field decay(t = 400.04): 6.38062097726398e-08 / 0.2500429210709593 = 2.5518102851842917e-07
# run 0 finished at t = 400.04 (80008 timesteps)

# %%
sim = mp.Simulation(cell_size=cell_size,
                    resolution=resolution,
                    boundary_layers=pml_layers,
                    sources=sources,
                    dimensions=1,
                    geometry=geometry)
tran = sim.add_flux(fcen, df, nf, tran_fr)
refl = sim.add_flux(fcen, df, nf, refl_fr)
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex,pt,1e-3))

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)
freqs = mp.get_flux_freqs(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000172853 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
#      block, center = (0,0,0.15)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,0.65)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,1.15)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,1.65)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,1.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,2.15)
#           size (1e+20,1e+20,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3,3,3)
#      block, center = (0,0,2.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 10 objects not shown)...
# time for set_epsilon = 0.000802994 s
# -----------
# field decay(t = 50.005): 7.327409614088478e-13 / 7.327409614088478e-13 = 1.0
# field decay(t = 100.01): 1.0032766779365554e-08 / 1.0032766779365554e-08 = 1.0
# field decay(t = 150.01500000000001): 5.2336057188386075e-06 / 5.2336057188386075e-06 = 1.0
# field decay(t = 200.02): 0.00014032556183043017 / 0.00014032556183043017 = 1.0
# field decay(t = 250.025): 0.0003000210211594207 / 0.0003000210211594207 = 1.0
# field decay(t = 300.03000000000003): 0.00029859360532880064 / 0.0003000210211594207 = 0.9952422806071926
# field decay(t = 350.035): 0.00023525021772238832 / 0.0003000210211594207 = 0.7841124492319642
# field decay(t = 400.04): 0.00021614402025637715 / 0.0003000210211594207 = 0.7204295866372835
# field decay(t = 450.045): 0.000202878369543335 / 0.0003000210211594207 = 0.6762138491473653
# field decay(t = 500.05): 0.0001904213298194991 / 0.0003000210211594207 = 0.6346932927686952
# field decay(t = 550.0550000000001): 0.0001787347613801691 / 0.0003000210211594207 = 0.5957407940598791
# field decay(t = 600.0600000000001): 0.00016751435800146634 / 0.0003000210211594207 = 0.5583420700126711
# field decay(t = 650.065): 0.00015723031913028644 / 0.0003000210211594207 = 0.5240643423006675
# field decay(t = 700.07): 0.00014757335912172416 / 0.0003000210211594207 = 0.4918767310084876
# field decay(t = 750.075): 0.00013851491317384688 / 0.0003000210211594207 = 0.4616840268010583
# field decay(t = 800.08): 0.00012981931593290138 / 0.0003000210211594207 = 0.43270073353933397
# field decay(t = 850.085): 0.0001218517484472243 / 0.0003000210211594207 = 0.40614403609564587
# on time step 179639 (time=898.195), 2.22669e-05 s/step
# field decay(t = 900.09): 0.00011436986835414373 / 0.0003000210211594207 = 0.3812061831939822
# field decay(t = 950.095): 0.00010734433799544594 / 0.0003000210211594207 = 0.357789389492168
# field decay(t = 4350.435): 1.4086098946257387e-06 / 0.0003000210211594207 = 0.004695037331658346
# field decay(t = 4400.4400000000005): 1.3221516389825008e-06 / 0.0003000210211594207 = 0.00440686333868571
# field decay(t = 4450.445): 1.2410007783412002e-06 / 0.0003000210211594207 = 0.004136379422833094
# field decay(t = 4500.45): 1.1647973699980379e-06 / 0.0003000210211594207 = 0.0038823858591532
# on time step 908566 (time=4542.83), 2.19084e-05 s/step
# field decay(t = 4550.455): 1.0916785884054225e-06 / 0.0003000210211594207 = 0.003638673664220823
# field decay(t = 4600.46): 1.0246236194517304e-06 / 0.0003000210211594207 = 0.0034151727618688464
# field decay(t = 4650.465): 9.61752188800911e-07 / 0.0003000210211594207 = 0.003205616010119069
# field decay(t = 4700.47): 9.027130340199266e-07 / 0.0003000210211594207 = 0.0030088326162327683
# field decay(t = 4750.475): 8.4604518325764e-07 / 0.0003000210211594207 = 0.0028199530152524916
# field decay(t = 4800.4800000000005): 7.940873367753157e-07 / 0.0003000210211594207 = 0.002646772328507493
# field decay(t = 4850.485): 7.453310314528018e-07 / 0.0003000210211594207 = 0.002484262697901954
# field decay(t = 4900.49): 6.995901691734315e-07 / 0.0003000210211594207 = 0.0023318038398439213
# field decay(t = 4950.495): 6.556726340325176e-07 / 0.0003000210211594207 = 0.002185422313072243
# field decay(t = 5000.5): 6.154176991250333e-07 / 0.0003000210211594207 = 0.0020512485983374537
# field decay(t = 5050.505): 5.77617523590117e-07 / 0.0003000210211594207 = 0.0019252568415304178
# field decay(t = 5100.51): 5.421661758997861e-07 / 0.0003000210211594207 = 0.0018070939622983882
# field decay(t = 5150.515): 5.088885525560337e-07 / 0.0003000210211594207 = 0.0016961763232104595
# field decay(t = 5200.52): 4.769427918911989e-07 / 0.0003000210211594207 = 0.0015896979153263002
# field decay(t = 5250.525000000001): 4.476563193655864e-07 / 0.0003000210211594207 = 0.0014920831801572912
# field decay(t = 5300.53): 4.201612441274046e-07 / 0.0003000210211594207 = 0.001400439350895168
# field decay(t = 5350.535): 3.9437940996266474e-07 / 0.0003000210211594207 = 0.0013145059250801805
# field decay(t = 5400.54): 3.6962155857124583e-07 / 0.0003000210211594207 = 0.0012319855360229635
# field decay(t = 5450.545): 3.4693173047625277e-07 / 0.0003000210211594207 = 0.0011563580749627052
# on time step 1092211 (time=5461.06), 2.17812e-05 s/step
# field decay(t = 5500.55): 3.2562530769384885e-07 / 0.0003000210211594207 = 0.0010853416418472321
# field decay(t = 5550.555): 3.056332012358289e-07 / 0.0003000210211594207 = 0.0010187059561850703
# field decay(t = 5600.56): 2.864463337263112e-07 / 0.0003000210211594207 = 0.0009547542122860238
# run 0 finished at t = 5600.56 (1120112 timesteps)

# %%
wvls = np.empty(nf)
R = np.empty(nf)
T = np.empty(nf)
for i in range(nf):
        wvls[i] = 1/freqs[i]*2*np.pi*3*10
        R[i] = -refl_flux[i]/empty_flux[i]
        T[i] = tran_flux[i]/empty_flux[i] 

plt.figure(dpi=150)#解析度
plt.plot(omega*300,T,'-',label='$T_{nur}$')#x軸omega y軸T
#plt.plot(omega/2/np.pi,R,'.',label='$T_{nur}$')
plt.xlabel("omega (THz)")
plt.ylabel("$T$")
#plt.xlim([fmin,fmax])
plt.ylim([0,1])
plt.savefig('5ABBA0.png')
plt.show()
